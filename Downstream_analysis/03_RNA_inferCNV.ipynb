# %%
# infercnv v1.14.0
library(infercnv)
library(phylogram)
library(pheatmap)
library(ggsci)
library(scales)
library(ggplot2)
library(RColorBrewer)

# %%
color <- c(c(pal_d3("category20")(20), "#B52D73", "#4347B5", "#4FED28", "#402727", "#48959C", "#FC6262", "#4A9EFF", "#9E969E"))
# specify colors
# tissue_color <- c("#33a02c","#e31a1c") #"#1f78b4",
tissue_color <- c("#2CA02CFF", "#E377C2FF")
celltype1_color <- c("#0072B5FF", "#D62728FF") # c(pal_nejm("default")(8)[c(2,1)])
celltype2_color <- c("#9467BDFF", "#FF95A8FF", "#8AA600", "#46732EFF", "#D62728FF")
celltype3_color <- c("#9467BDFF", "#FF95A8FF", "#8AA600", "#46732EFF", "#D62728FF", "#FD7446FF", "#8A9197FF")
celltype4_color <- c("#20854EFF", "#008EA0FF", "#FF6F00FF", "#C71000FF")

patient_color <- c(
  "#FED439FF", "#8A9197FF", "#8A4198FF", "#D5E4A2FF", "#197EC0FF", "#FD7446FF", "#46732EFF", "#71D0F5FF", "#E377C2FF",
  "#075149FF", "#e60000", "#91331FFF", "#1A9993FF", "#ff80aa", "#D2AF81FF", "#370335FF", "#cc99ff", "#ff8000", "#59b300"
)

# %%
gene_cts <- read.table(file = "00_gene_counts_12291genes.txt", header = T, row.names = 1, sep = "\t")

# %%
gene_cts <- as.matrix(gene_cts)
gene_cts[1:2, 1:2]
# Out:
#          CRC01_L1_Barcode01 CRC01_L1_Barcode02
# MTCO1P12 0                  1
# MTATP8P1 0                  0

# %%
infercnv_obj <- CreateInfercnvObject(
  raw_counts_matrix = gene_cts,
  annotations_file = "00_anno_crc_patient_tissue.txt",
  delim = "\t",
  gene_order_file = "00_gene_ordering_file.txt",
  ref_group_names = c("CRC01-NT", "CRC02-NT", "CRC03-NT", "CRC04-NT", "CRC05-NT", "CRC07-NT", "CRC08-NT", "CRC09-NT", "CRC10-NT")
)
# Out:
# INFO [2023-01-12 12:57:47] Parsing gene order file: 00_gene_ordering_file.txt
# INFO [2023-01-12 12:57:47] Parsing cell annotations file: 00_anno_crc_patient_tissue.txt
# INFO [2023-01-12 12:57:47] ::order_reduce:Start.
# INFO [2023-01-12 12:57:48] .order_reduce(): expr and order match.
# INFO [2023-01-12 12:57:48] ::process_data:order_reduce:Reduction from positional data, new dimensions (r,c) = 12291,1395 Total=180376311.780204 Min=0 Max=183513.5.
# INFO [2023-01-12 12:57:48] num genes removed taking into account provided gene ordering list: 408 = 3.3195020746888% removed.
# INFO [2023-01-12 12:57:48] -filtering out cells < 100 or > Inf, removing 0 % of cells
# WARN [2023-01-12 12:57:48] Please use "options(scipen = 100)" before running infercnv if you are using the analysis_mode="subclusters" option or you may encounter an error while the hclust is being generated.
# INFO [2023-01-12 12:57:49] validating infercnv_obj

# %%
# Time-consuming
infercnv_obj <- infercnv::run(
  infercnv_obj,
  cutoff = 1, # cutoff=1 works well for Smart-seq2, and cutoff=0.1 works well for 10x Genomics
  out_dir = "patient_tissue",
  cluster_by_groups = TRUE,
  denoise = TRUE,
  HMM = TRUE
)
# Out:
# INFO [2023-01-12 12:58:16] ::process_data:Start
# INFO [2023-01-12 12:58:16] Creating output path patient_tissue
# INFO [2023-01-12 12:58:16] Checking for saved results.
# INFO [2023-01-12 12:58:16]
#
# 	STEP 1: incoming data
#
# INFO [2023-01-12 12:58:22]
#
# 	STEP 02: Removing lowly expressed genes
#
# INFO [2023-01-12 12:58:22] ::above_min_mean_expr_cutoff:Start
# INFO [2023-01-12 12:58:22] Removing 3661 genes from matrix as below mean expr threshold: 1
# INFO [2023-01-12 12:58:23] validating infercnv_obj
# INFO [2023-01-12 12:58:23] There are 8222 genes and 1395 cells remaining in the expr matrix.
# INFO [2023-01-12 12:58:23] no genes removed due to min cells/gene filter
# INFO [2023-01-12 12:58:28]
#
# 	STEP 03: normalization by sequencing depth
#
# INFO [2023-01-12 12:58:28] normalizing counts matrix by depth
# INFO [2023-01-12 12:58:28] Computed total sum normalization factor as median libsize: 75190.134140
# INFO [2023-01-12 12:58:29] Adding h-spike
# INFO [2023-01-12 12:58:29] -hspike modeling of CRC01-NT
# INFO [2023-01-12 12:59:40] -hspike modeling of CRC02-NT
# INFO [2023-01-12 13:00:51] -hspike modeling of CRC03-NT
# INFO [2023-01-12 13:02:02] -hspike modeling of CRC04-NT
# INFO [2023-01-12 13:03:14] -hspike modeling of CRC05-NT
# INFO [2023-01-12 13:04:26] -hspike modeling of CRC07-NT
# INFO [2023-01-12 13:05:37] -hspike modeling of CRC08-NT
# INFO [2023-01-12 13:06:48] -hspike modeling of CRC09-NT
# INFO [2023-01-12 13:07:59] -hspike modeling of CRC10-NT
# INFO [2023-01-12 13:09:13] validating infercnv_obj
# INFO [2023-01-12 13:09:13] normalizing counts matrix by depth
# INFO [2023-01-12 13:09:13] Using specified normalization factor: 75190.134140
# INFO [2023-01-12 13:09:26]
#
# 	STEP 04: log transformation of data
#
# INFO [2023-01-12 13:09:26] transforming log2xplus1()
# INFO [2023-01-12 13:09:26] -mirroring for hspike
# INFO [2023-01-12 13:09:26] transforming log2xplus1()
# INFO [2023-01-12 13:09:39]
#
# 	STEP 08: removing average of reference data (before smoothing)
#
# INFO [2023-01-12 13:09:39] ::subtract_ref_expr_from_obs:Start inv_log=FALSE, use_bounds=TRUE
# INFO [2023-01-12 13:09:39] subtracting mean(normal) per gene per cell across all data
# INFO [2023-01-12 13:09:42] -subtracting expr per gene, use_bounds=TRUE
# INFO [2023-01-12 13:09:44] -mirroring for hspike
# INFO [2023-01-12 13:09:44] ::subtract_ref_expr_from_obs:Start inv_log=FALSE, use_bounds=TRUE
# INFO [2023-01-12 13:09:44] subtracting mean(normal) per gene per cell across all data
# INFO [2023-01-12 13:09:47] -subtracting expr per gene, use_bounds=TRUE
# INFO [2023-01-12 13:10:05]
#
# 	STEP 09: apply max centered expression threshold: 3
#
# INFO [2023-01-12 13:10:05] ::process_data:setting max centered expr, threshold set to: +/-:  3
# INFO [2023-01-12 13:10:05] -mirroring for hspike
# INFO [2023-01-12 13:10:05] ::process_data:setting max centered expr, threshold set to: +/-:  3
# INFO [2023-01-12 13:10:20]
#
# 	STEP 10: Smoothing data per cell by chromosome
#
# INFO [2023-01-12 13:10:20] smooth_by_chromosome: chr: chr1
# INFO [2023-01-12 13:10:22] smooth_by_chromosome: chr: chr2
# INFO [2023-01-12 13:10:23] smooth_by_chromosome: chr: chr3
# INFO [2023-01-12 13:10:24] smooth_by_chromosome: chr: chr4
# INFO [2023-01-12 13:10:25] smooth_by_chromosome: chr: chr5
# INFO [2023-01-12 13:10:27] smooth_by_chromosome: chr: chr6
# INFO [2023-01-12 13:10:28] smooth_by_chromosome: chr: chr7
# INFO [2023-01-12 13:10:30] smooth_by_chromosome: chr: chr8
# INFO [2023-01-12 13:10:31] smooth_by_chromosome: chr: chr9
# INFO [2023-01-12 13:10:32] smooth_by_chromosome: chr: chr10
# INFO [2023-01-12 13:10:34] smooth_by_chromosome: chr: chr11
# INFO [2023-01-12 13:10:35] smooth_by_chromosome: chr: chr12
# INFO [2023-01-12 13:10:37] smooth_by_chromosome: chr: chr13
# INFO [2023-01-12 13:10:38] smooth_by_chromosome: chr: chr14
# INFO [2023-01-12 13:10:39] smooth_by_chromosome: chr: chr15
# INFO [2023-01-12 13:10:40] smooth_by_chromosome: chr: chr16
# INFO [2023-01-12 13:10:42] smooth_by_chromosome: chr: chr17
# INFO [2023-01-12 13:10:43] smooth_by_chromosome: chr: chr18
# INFO [2023-01-12 13:10:44] smooth_by_chromosome: chr: chr19
# INFO [2023-01-12 13:10:45] smooth_by_chromosome: chr: chr20
# INFO [2023-01-12 13:10:47] smooth_by_chromosome: chr: chr21
# INFO [2023-01-12 13:10:47] smooth_by_chromosome: chr: chr22
# INFO [2023-01-12 13:10:49] -mirroring for hspike
# INFO [2023-01-12 13:10:49] smooth_by_chromosome: chr: chrA
# INFO [2023-01-12 13:10:51] smooth_by_chromosome: chr: chr_0
# INFO [2023-01-12 13:10:53] smooth_by_chromosome: chr: chr_B
# INFO [2023-01-12 13:10:56] smooth_by_chromosome: chr: chr_0pt5
# INFO [2023-01-12 13:10:58] smooth_by_chromosome: chr: chr_C
# INFO [2023-01-12 13:11:00] smooth_by_chromosome: chr: chr_1pt5
# INFO [2023-01-12 13:11:02] smooth_by_chromosome: chr: chr_D
# INFO [2023-01-12 13:11:04] smooth_by_chromosome: chr: chr_2pt0
# INFO [2023-01-12 13:11:06] smooth_by_chromosome: chr: chr_E
# INFO [2023-01-12 13:11:08] smooth_by_chromosome: chr: chr_3pt0
# INFO [2023-01-12 13:11:11] smooth_by_chromosome: chr: chr_F
# INFO [2023-01-12 13:11:33]
#
# 	STEP 11: re-centering data across chromosome after smoothing
#
# INFO [2023-01-12 13:11:33] ::center_smooth across chromosomes per cell
# INFO [2023-01-12 13:11:35] -mirroring for hspike
# INFO [2023-01-12 13:11:35] ::center_smooth across chromosomes per cell
# INFO [2023-01-12 13:11:54]
#
# 	STEP 12: removing average of reference data (after smoothing)
#
# INFO [2023-01-12 13:11:54] ::subtract_ref_expr_from_obs:Start inv_log=FALSE, use_bounds=TRUE
# INFO [2023-01-12 13:11:54] subtracting mean(normal) per gene per cell across all data
# INFO [2023-01-12 13:11:58] -subtracting expr per gene, use_bounds=TRUE
# INFO [2023-01-12 13:11:59] -mirroring for hspike
# INFO [2023-01-12 13:11:59] ::subtract_ref_expr_from_obs:Start inv_log=FALSE, use_bounds=TRUE
# INFO [2023-01-12 13:11:59] subtracting mean(normal) per gene per cell across all data
# INFO [2023-01-12 13:12:03] -subtracting expr per gene, use_bounds=TRUE
# INFO [2023-01-12 13:12:20]
#
# 	STEP 14: invert log2(FC) to FC
#
# INFO [2023-01-12 13:12:20] invert_log2(), computing 2^x
# INFO [2023-01-12 13:12:20] -mirroring for hspike
# INFO [2023-01-12 13:12:20] invert_log2(), computing 2^x
# INFO [2023-01-12 13:12:35]
#
# 	STEP 15: computing tumor subclusters via leiden
#
# INFO [2023-01-12 13:12:35] define_signif_tumor_subclusters(p_val=0.1
# INFO [2023-01-12 13:12:35] define_signif_tumor_subclusters(), tumor: CRC01-PT
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  CCNG1, ATP10B, HMMR, MAT2B, PTTG1, SLU7, WWC1, FABP6, RARS1, PWWP2A
# 	   TTC1, UBLCP1, PANK3, CLINT1, C5orf52, RPL10P9, CYFIP2, SPDL1, MED7, RANBP17
# 	   MRPL22, NPM1, FBXW11, CNOT8, STK10, FAXDC2, UBTD2, LARP1, SH3PXD2B, DUSP1
# Negative:  PSMG3, ELFN1-AS1, GTF2IRD1, GTF2I, CLIP2, RFC2, MAD1L1, EIF4H, RCC1L, CCL24
# 	   RHBDD2, MDH2, GTF2IRD2B, MRM2, STYXL1, POM121C, HSPB1, TMEM120A, NSUN5P1, ZP3
# 	   NUDT1, DTX2, LRRC61, RARRES2, ACTR3C, EIF3B, REPIN1, ATP6V0E2, GIMAP2, ZNF212
# PC_ 2
# Positive:  RNF185, SELENOM, SMTN, TUG1, LIMK2, DUSP18, PIK3IP1, SLC35E4, PATZ1, TCN2
# 	   DRG1, PES1, SFI1, MTFP1, PISD, YWHAH, TBC1D10A, RTCB, ASCC2, FBXO7
# 	   UQCR10, TIMP3, NIPSNAP1, LARGE1, ISX, THOC5, AP1B1, HMGXB4, EWSR1, TOM1
# Negative:  LY6G6D, CSNK2B, ABHD16A, GPANK1, LY6G6C, C6orf47, DDAH2, APOM, BAG6, CLIC1
# 	   PRRC2A, MSH5, TNF, SAPCD1, NFKBIL1, VARS1, LSM2, DDX39B, HSPA1A, HSPA1B
# 	   HCP5, SNHG32, NEU1, EHMT2, MICA, C2, CFB, HLA-B, NELFE, SKIV2L
# PC_ 3
# Positive:  CRY1, PRDM4, PWP1, SART3, MTERF2, ISCU, TMEM263, CORO1C, RIC8B, USP30
# 	   C12orf75, APPL2, ALKBH2, UNG, WASHC4, KCTD10, NOPCHAP1, UBE3B, ERP29, NAA25
# 	   TMEM116, BRAP, MAPKAPK5, ATXN2, ACAD10, RPL18AP3, MMAB, MAPKAPK5-AS1, PPP1CC, MVK
# Negative:  POLD4, SSH3, CLCF1, ANKRD13D, PPP1CA, KDM2A, RPS6KB2, TMEM134, RHOD, AIP
# 	   PITPNM1, PC, CDK2AP2, RCE1, C11orf80, RBM4B, RBM4, PKD1-AS1, SNHG19, TSC2
# 	   TRAF7, RBM14-RBM4, NTHL1, SLC9A3R2, NPW, MLST8, GFER, RBM14, NOXO1, PGP
# PC_ 4
# Positive:  LINC02894, ESRP1, VIRMA, CIBAR1, RAD54B, TRIQK, PDP1, DPY19L4, GEM, INTS8
# 	   OTUD6B, CCNE2, PIP4P2, DECR1, NDUFAF6, NBN, OSGIN2, RMDN1, CPNE3, CA2
# 	   CA1, RBIS, E2F5, SNX16, CHMP4C, ZFAND1, IMPA1, FABP5, ZBTB10, TPD52
# Negative:  FKBP5, SRPK1, TEAD3, RPL10A, MAPK14, MAPK13, DEF6, ZNF76, ANKS1A, BRPF3
# 	   TAF11, BNIP5, SNRPC, ETV7, ILRUN, KCTD20, SPDEF, RPS10, STK38, NUDT3
# 	   SRSF3, SMIM29, CDKN1A, HMGA1, LEMD2, UQCC2, PPIL1, ITPR3, C6orf89, BAK1
# PC_ 5
# Positive:  HIP1R, DENR, VPS37B, RSRC2, OGFOD2, ARL6IP4, CLIP1, VPS33A, MTRFR, CDK2AP1
# 	   DIABLO, RILPL2, SNRNP35, SBNO1, MLXIP, LINC02985, RFLNA, SCARB1, UBC, TMED2
# 	   ZNF664, AACS, ATP6V0A2, BCL7A, DDX55, GTF2H3, EIF2B1, PSMD9, SLC15A4, RAN
# Negative:  EYA3, XKR8, SMPDL3B, RPA2, STX12, FAM76A, IFI6, WASF2, SYTL1, TMEM222
# 	   SLC9A1, KDF1, NR0B2, NUDC, GPATCH3, GPN2, SFN, ARID1A, PIGV, RPS6KA1
# 	   HMGN2, DHDDS, UBXN11, SH3BGRL3, CNKSR1, ZNF593, PAFAH2, STMN1, MTFR1L, LDLRAP1
#
# Computing nearest neighbor graph
#
# Computing SNN
# INFO [2023-01-12 13:12:36] define_signif_tumor_subclusters(), tumor: CRC02-PT
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  FARP1, SLC15A1, STK24, UBAC2, IPO5, TM9SF2, RAP2A, CLYBL, PCCA-DT, MBNL2
# 	   PCCA, OXGR1, GGACT, UGGT2, TMTC4, DNAJC3, TPP2, DNAJC3-DT, TEX30, TGDS
# 	   SPRY2, BIVM, NDFIP2, RBM26, ERCC5, OBI1, MYCBP2, EFNB2, FBXL3, ARGLU1
# Negative:  NAXE, CCT3, GPATCH4, CRABP2, GLMP, ISG20L2, NCLN, ZNF77, TLE2, NFIC
# 	   TLE5, ZNF57, TMEM79, SMIM24, THOP1, METTL25B, DOHH, SGTA, MFSD12, SLC39A3
# 	   HMG20B, SMG5, APBA3, HDGF, MRPL54, GADD45B, FAM98C, PSMD8, KCNK6, EIF3K
# PC_ 2
# Positive:  ZNF586, ZNF419, ZNF587, ZNF552, ZNF749, ZNF274, TRAPPC2B, ZNF544, ERVK3-1, RPS5
# 	   ZNF584, AURKAIP1, CCNL2, CPTP, MRPL20, ATAD3B, MRPL20-AS1, ATAD3A, SSU72, ZNF324
# 	   INTS11, PUSL1, MIB2, UBE2J2, C1QTNF12, ZNF446, SDF4, SLC35E2B, C1orf159, SLC27A5
# Negative:  FASTKD2, EEF1B2, KLF7, CREB1, INO80D-AS2, METTL21A, ABI2, FHL3, UTP11, FZD5
# 	   CYP20A1, NOP58, FAM117B, WDR12, MYCBP, SUMO1, CAP1, NBEAL1, MFSD2A, MYCL
# 	   TMEM237, IDH1, RHBDL2, TRIT1, STRADB, PPIE, PPT1, AKIRIN1, PABPC4, CASP8
# PC_ 3
# Positive:  SEPTIN10, MTLN, CCDC138, SOWAHC, NPHP1, RANBP2, MALL, GCC2, RNF149, IL1R2
# 	   SLC9A2, MFSD9, SULT1C2, CNOT11, UXS1, TMEM182, NCK2, FHL2, MRPS9, TGFBRAP1
# 	   RPL31, C2orf49, NPAS2, PDCL3, REV1, EIF5B, TXNDC9, TBL3, NOXO1, SNHG9
# Negative:  TMEM9, LAD1, INAVA, CSRP1, DDX59, IPO9, ZNF281, TIMM17A, NR5A2, NEK7
# 	   RNPEP, C1orf53, DENND1B, ELF3, CDC73, ARL8A, GLRX2, RO60, LGR6, UCHL5
# 	   RGS2, TPR, UBE2T, IVNS1ABP, PPP1R12B, TRMT1L, RNF2, KDM5B, EDEM3, PCAT6
# PC_ 4
# Positive:  GCNT3, GTF2A2, BNIP2, MYO1E, RPS3AP6, CCNB2, SLTM, ANXA2, VPS13C, MINDY2
# 	   TPM1, ADAM10, LACTB, POLR2M, RPS27L, MYZAP, TCF12, ZNF280D, CCPG1, PIGB
# 	   PIGBOS1, PPHLN1, ZCRB1, KIF21A, PUS7L, PKP2, IRAK4, TWF1, TMEM117, SCAF11
# Negative:  ZYX, CASP2, TMEM139, EPHA1, ARHGEF5, GSTK1, SSBP1, TPK1, DENND11, CUL1
# 	   AGK, EZH2, MRPS33, NDUFB2, PDIA4, ADCK2, MKRN1, ZNF212, ATP6V0E2, ACTR3C
# 	   RAB19, LRRC61, RARRES2, REPIN1, GIMAP2, SLC37A3, TMEM176B, TMEM176A, KDM7A-DT, AOC1
# PC_ 5
# Positive:  EFCAB7, ITGB3BP, PGM1, ALG6, RAVER2, ATG4C, USP1, JAK1, PATJ, AK4
# 	   TM2D1, NFIA, LEPROT, HOOK1, FGGY, INSL5, LINC01135, MIER1, JUN, SLC35D1
# 	   MYSM1, SERBP1, TACSTD2, GADD45A, OMA1, GNG12, PLPP3, WLS, PCSK9, LRRC40
# Negative:  LGMN, GOLGA5, CPSF2, ITPK1, NDUFB1, MOAP1, TMEM251, UBR7, ATXN3, DDX24
# 	   TRIP11, IFI27L1, TC2N, IFI27, PPP4R3A, IFI27L2, DGLUCY, SERPINA6, RPS6KA5, SERPINA1
# 	   CALM1, TDP1, DICER1, FOXN3, SNHG10, TTC8, GLRX5, ZC3H14, GSKIP, SPATA7
#
# Computing nearest neighbor graph
#
# Computing SNN
# INFO [2023-01-12 13:12:37] define_signif_tumor_subclusters(), tumor: CRC03-PT
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  LRRC49, THAP10, UACA, MYO9A, TLE3, PKM, DRAIC, PARP6, RPLP1, HEXA
# 	   ARIH1, GLCE, BBS4, ANP32A, ADPGK, NEO1, CLN6, CD276, CALML4, PML
# 	   PIAS1, UBL7, MAP2K5, CLK3, SERF2, AAGAB, MFAP1, GOLM2, ELL3, EIF3J-DT
# Negative:  SPAG7, PFN1, ZNF232, RABEP1, RNF167, SLC25A11, NUP88, MINK1, RPAIN, COA7
# 	   PSMB6, DERL2, RPS13P2, MIS12, ECHDC2, PIMREG, SCP2, TM4SF5, TXNDC17, SLC1A7
# 	   CXCL16, MED31, C17orf100, CPT2, XAF1, MEA1, MED11, KLHDC3, PPP2R5D, CNPY3
# PC_ 2
# Positive:  EMC9, PSME2, DCAF11, RNF31, IRF9, IPO4, PCK2, TM9SF1, DHRS4L2, CHMP4A
# 	   DHRS4, MDP1, DHRS4-AS1, NEDD8, GMPR2, AP1G2, TINF2, THTPA, RABGGTA, NGDN
# 	   PABPN1, DHRS1, BCL2L2-PABPN1, ADCY4, BCL2L2, RIPK3, KHNYN, C14orf119, SDR39U1, ACIN1
# Negative:  RPS9, LENG8, TSEN34, MBOAT7, TMC4, CDC42EP5, LENG1, TFPT, NDUFA3, MYADM
# 	   NLRP2, ZNF331, RDH13, EPS8L1, ZNF761, TNNI3, EPN1, ZNF581, ZNF580, ZNF444
# 	   PTPRH, ZNF524, ZSCAN5A, ISOC2, UBE2S, PPP6R1, ZNF160, TRAPPC2B, RPL28, HSPBP1
# PC_ 3
# Positive:  SH3RF2, LARS1, PRELID2, RBM27, TCERG1, YIPF5, ARHGAP26, SPRY4, SPINK1, NDFIP1
# 	   GNPDA1, RNF14, FBXO38, DELE1, PCDH1, FCHSD1, PCYOX1L, RELL2, CSNK1A1, HDAC3
# 	   SLC26A2, DIAPH1, HMGXB3, TAF7, ZMAT2, CDX1, HARS2, HARS1, TCOF1, WDR55
# Negative:  EIF5A, GPS2, CLDN7, TNK1, TMEM256, ELP5, CHRNB1, CTDNEP1, TNFSF13, GABARAP
# 	   PHF23, EIF4A1, DVL2, CD68, ACADVL, MPDU1, C17orf49, SAT2, RNASEK-C17orf49, TP53
# 	   RNASEK, WRAP53, ALOX12-AS1, NAA38, XAF1, TRAPPC1, C17orf100, MED31, PER1, TXNDC17
# PC_ 4
# Positive:  COX18, ANKRD17, DCK, RASSF6, TFRC, PCYT1A, MUC4, CXCL8, MUC20, DYNLT2B
# 	   CXCL1, MUC20-OT1, GRSF1, WDR53, RNF168, PF4, PIGX, PAK2, MUC20P1, PPBP
# 	   SENP5, HES1, NCBP2, CXCL3, OPA1, TMEM44-AS1, TMEM44, LSG1, PPP1R2, CLDN1
# Negative:  MRPL27, XYLT2, TMEM92, LRRC59, PDK2, ITGA3, KAT7, ACSF2, RSAD1, SLC35B1
# 	   EPN3, SPATA20, SPOP, ABCC3, LUC7L3, ANKRD40CL, TOB1, TOB1-AS1, PHB1, SPAG9
# 	   NME1, NME1-NME2, SNF8, NME2, UTP18, UBE2Z, TOM1L1, MMD, PCTP, TRIM25
# PC_ 5
# Positive:  FABP1, EIF2AK3, THNSL2, KRCC1, RPIA, CYTOR, RMND5A, IGKC, RNF103, MRPS5
# 	   CHMP3, ZNF514, KDM3A, FAHD2A, MRPL35, USP39, RNF181, VAMP5, C2orf68, PTCD3
# 	   IMMT, ANKRD36C, VAMP8, GGCX, ACHE, SRRT, UFSP1, MUC12, DUSP2, TRIP6
# Negative:  RAB40C, METTL26, MCRIP2, PIGQ, DECR2, NME4, WDR90, STUB1, JMJD8, TTC8
# 	   FOXN3, WDR24, RHOT2, PGAP6, ZC3H14, TDP1, ANTKMT, CALM1, SPATA7, HAGHL
# 	   SEL1L, MRPL28, RPS6KA5, AXIN1, GTF2A1, CIAO3, FAM234A, MSLN, DGLUCY, ADCK1
#
# Computing nearest neighbor graph
#
# Computing SNN
# INFO [2023-01-12 13:12:37] define_signif_tumor_subclusters(), tumor: CRC04-PT
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  NUP37, WASHC3, PARPBP, HSP90B1, GNPTAB, C12orf73, CHPT1, ARL1, TDG, NFYB
# 	   TXNRD1, GAS2L3, RPL18AP3, NOPCHAP1, SCYL2, WASHC4, APPL2, C12orf75, ACTR6, RIC8B
# 	   TMEM263, MTERF2, CRY1, SLC25A3, PWP1, PRDM4, SART3, ISCU, CORO1C, TMPO
# Negative:  MRPL20-AS1, CCNL2, AURKAIP1, MRPL20, CPTP, ATAD3B, ATAD3A, INTS11, SSU72, PUSL1
# 	   UBE2J2, C1QTNF12, SDF4, MIB2, C1orf159, SLC35E2B, ISG15, NOC2L, LINC01128, CDK11A
# 	   NADK, GNB1, TMEM52, PRKCZ, FAAP20, RER1, PEX10, PANK4, TNFRSF14-AS1, TNFRSF14
# PC_ 2
# Positive:  PLA2G4C, SELENOW, NOP53, NAPA, KPTN, DHX34, INAFM1, SAE1, TMEM160, AP2S1
# 	   SLC1A5, STRN4, WDR83, DHPS, WDR83OS, FBXW9, PRKD2, TRIR, CALM3, GET3
# 	   HOOK2, PPP5C, JUNB, FOXA3, SYMPK, DMPK, SNRPD2, EML2, VASP, FOSB
# Negative:  CAVIN3, FHIP1B, TRIM5, TRIM3, TRIM34, ARFIP2, TIMM10B, RRP8, TRIM68, ILK
# 	   TPP1, TAF10, MRPL17, ZNF215, PPFIBP2, TRIM21, CYB5R2, EIF3F, RPL27A, DENND2B
# 	   AKIP1, TMEM9B, DENND5A, TMEM41B, IPO7, ZNF143, SWAP70, ADM, RNF141, GNG12
# PC_ 3
# Positive:  TERF2, NIP7, CYB5B, KARS1, NFAT5, TERF2IP, PDF, FCSK, DDX19A, ADAT1
# 	   GABARAPL2, MON1B, TMEM231, DDX19B, COG4, NQO1, TMEM170A, WWP2, AARS1, NPIPB14P
# 	   NOB1, PDXDC2P-NPIPB14P, SF3B3, CFDP1, VAC14, BCAR1, LDHD, CMTR2, WDR59, FA2H
# Negative:  LIMA1, LARP4, CERS5, DIP2B, COX14, RACGAP1, ATF1, TMBIM6, METTL7A, MCRS1
# 	   SLC11A2, SPATS2, LETMD1, DNAJC22, TROAP, TFCP2, TUBA1C, DAZAP2, TUBA1A, TUBA1B
# 	   LMBR1L, SMAGP, PRKAG1, ARF3, FKBP11, GALNT6, RND1, DDX23, ACVRL1, NR4A1
# PC_ 4
# Positive:  IRF2BP2, TOMM20, TARBP1, RBM34, COA6, ARID4B, KCNK1, GGPS1, ZDHHC4, INTS15
# 	   KDELR2, TBCE, DAGLB, MAP3K21, RAC1, NTPCR, B3GALNT2, FAM220A, TSNAX, GNG4
# 	   EIF2AK1, EGLN1, AIMP2, GPR137B, SPRTN, PMS2, GNPAT, LGALS8, RNF216, C1orf131
# Negative:  COPS7A, ZNF384, MLF2, ING4, PTMS, LPAR5, CDCA3, TPI1, CHD4, SPSB2
# 	   RPL13P5, LRRC23, NOP2, ENO2, C12orf57, GAPDH, PTPN6, MIR200CHG, NCAPD2, PHB2
# 	   MRPL51, TAPBPL, EMG1, CD27-AS1, LPCAT3, LTBR, C1RL, SCNN1A, TNFRSF1A, APOBEC1
# PC_ 5
# Positive:  NDE1, CEP20, PARN, ABCC1, RPS15A, CPPED1, ERI2, ARL6IP1, REXO5, SNX29
# 	   THUMPD1, LYRM1, SMG1, GSPT1, LDAF1, TMC7, COQ7, IQCK, ANKS4B, RSL1D1
# 	   TMC5, KNOP1, VPS35L, GDE1, ZC3H7A, CRYM, TXNDC11, SLC7A5P2, LITAF, METTL9
# Negative:  MFSD10, ADD1, NOP14, TMEM129, TACC3, LETM1, SLBP, HTT, TNIP2, TMEM128
# 	   NSD2, RNF4, LYAR, MXD4, HAUS3, MAEA, NELFA, C4orf48, STX18, WFS1
# 	   CTBP1, SPON2, MRFAP1, FGFRL1, S100P, TMEM175, MRFAP1L1, GAK, BLOC1S4, PCGF3-AS1
#
# Computing nearest neighbor graph
#
# Computing SNN
# INFO [2023-01-12 13:12:38] define_signif_tumor_subclusters(), tumor: CRC05-PT
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  NUP107, RAP1B, CPM, CPSF6, MDM1, DYRK2, LYZ, TMBIM4, YEATS4, CCT2
# 	   LEMD3, RAB3IP, GNS, CNOT2, TBK1, XPOT, SRGAP1, KICS2, PTPRR, RXYLT1
# 	   TSPAN8, RPL14P1, ZFC3H1, USP15, THAP2, TMEM19, LRIG3, TBC1D15, ATXN7L3B, ATP23
# Negative:  PAK4, PAF1, MED29, ZFP36, RPS16, SUPT5H, TIMM50, FBL, PSMC4, EPS15L1
# 	   AP1M1, SCAPER, ETFA, RCN2, TSPAN3, IDH3A, HMG20A, DNAJA4, YJU2, CCNF
# 	   FAM32A, RNPS1, WDR61, ECI1, IREB2, E4F1, PGP, SIRT6, HSH2D, PSMA4
# PC_ 2
# Positive:  RPL6P27, LINC00668, NDUFV2, ANKRD12, TWSG1, RALBP1, PPP4R1, VAPA, APCDD1, NAPG
# 	   CHMP1B, MPPE1, IMPA2, DOP1B, CBR3-AS1, MORC3, CBR1, PIGP, SETD4, TTC3
# 	   RCAN1, AFG3L2, VPS26C, ETS2, SLC5A3, PSMG1, PSMG2, MRPS6, BRWD1, ATP5PO
# Negative:  STK10, FBXW11, UBTD2, SH3PXD2B, DUSP1, NPM1, RANBP17, ERGIC1, SPDL1, RPL26L1
# 	   RPL10P9, PANK3, ATP6V0E1, RARS1, CREBRF, WWC1, BNIP1, MAT2B, BOD1, MSX2
# 	   SFXN1, HMMR, THOC3, SIMC1, CCNG1, KIAA1191, NOP16, ATP10B, HIGD2A, CLTB
# PC_ 3
# Positive:  ADAM17, IAH1, CPSF3, ITGB1BP1, ACTR2, C1D, VDAC2P5, DNAAF10, MBOAT2, PNO1
# 	   RAB1A, AFTPH, LINC02245, SLC1A4, CEP68, LGALSL, PELI1, NFU1, UGP2, MDH1
# 	   GMCL1, PCYOX1, TIA1, SNRPG, B3GNT2, SNRNP27, C2orf42, FAM136A, PCBP1, COMMD1
# Negative:  HEIH, MGAT1, MAPK9, LINC00847, RNF130, MRNIP, TBC1D9B, ZFP62, SQSTM1, MGAT4B
# 	   BTNL8, CANX, HNRNPH1, BTNL3, RUFY1, ZNF354A, CLK4, SLCO3A1, FAM174B, VPS33B
# 	   CHASERR, PHYKPL, CHD2, PRC1, MCTP2, RCCD1, UNC45A, NHP2, ARRDC4, HDDC3
# PC_ 4
# Positive:  STK17B, GTF3C3, SLC39A10, SF3B1, NABP1, COQ10B, MYO1B, HSPD1, HSPE1, STAT1
# 	   MOB4, MARS2, GLS, SATB2, NAB1, SATB2-AS1, MFSD6, C2orf69, TYW5, INPP1
# 	   MAIP1, HIBCH, SPATS2L, GGCX, MORN2, VAMP8, PMS1, VAMP5, MAT2A, RNF181
# Negative:  MRPS34, NME3, SPSB3, NUBP2, JPT2, CLCN7, HAGH, C16orf91, FAHD1, GNPTG
# 	   MSRB1, NDUFB10, TSR3, RPS2, SNHG9, UBE2I, TBL3, TPSG1, NOXO1, LMF1
# 	   GFER, CHTF18, NPW, RPUSD1, SLC9A3R2, MSLN, NTHL1, CIAO3, HAGHL, TSC2
# PC_ 5
# Positive:  TMEM98, PSMD11, ZNF830, LIG3, RFFL, ZNF207, RAD51D, PEX12, RHOT1, AP2B1
# 	   SUZ12, MMP28, UTP6, TAF15, COPRS, RAB11FIP4, NF1, RNF135, TEFM, CRLF3
# 	   GOSR1, CPD, TMIGD1, BLMH, NSRP1, SSH2, GIT1, TP53I13, ABHD15, NUFIP2
# Negative:  CARD10, MFNG, CDC42EP1, RAC2, LGALS2, MPST, TST, GGA1, LGALS1, NCF4
# 	   NOL12, H1-0, IFT27, ANKRD54, EIF3D, EIF3L, TXN2, POLR2F, MYH9, PICK1
# 	   APOL2, BAIAP2L2, RBFOX2, MAFF, MB, TMEM184B, ZNF587, TOM1, CSNK1E, ZNF274
#
# Computing nearest neighbor graph
#
# Computing SNN
# INFO [2023-01-12 13:12:38] define_signif_tumor_subclusters(), tumor: CRC07-PT
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  PIWIL4, ANKRD49, PANX1, MED17, MRE11, C11orf54, FUT4, TAF1D, CEP57, ENDOD1
# 	   MTMR2, SRSF8, CWC15, CCDC82, SMCO4, JRKL, BIRC3, BIRC2, CHORDC1, TMEM123
# 	   CTSC, MMP7, PRSS23, MMP1, DCUN1D5, ME3, CASP4, HIKESHI, EED, CASP5
# Negative:  PPT1, CAP1, RLF, ZMPSTE24-DT, ZMPSTE24, MFSD2A, SMAP2, MYCL, EXO5, MET
# 	   CAPZA2, TES, STMP1, MTPN, NFYC, SMIM30, TRIT1, NUP205, TMEM168, IFRD1
# 	   ST7, CREB3L2, ZNF277, CTPS1, CNOT4, DNAJB9, HBP1, PNPLA8, NAMPT, PPIE
# PC_ 2
# Positive:  SKA3, SAP18, IFT88, CRYL1, GJB2, ZMYM2, ZMYM5, CDC42EP2, DPF2, YWHAQ
# 	   ADAM17, TAF1B, FRMD8, IAH1, KLF11, RRM2, HPCAL1, ODC1, CPSF3, NEAT1
# 	   NOL10, PDIA6, SLC66A3, MALAT1, ITGB1BP1, PCID2, ROCK2, SCYL1, NUBP2, F10
# Negative:  MYOF, CEP55, BTAF1, FFAR4, PCGF5, RPP30, KIF20B, FRA10AC1, PANK1, IFIT3
# 	   NOC3L, LIPA, CYP2C18, FAS, PDLIM1, SORBS1, STAMBPL1, TCTN3, ENTPD1-AS1, ANKRD22
# 	   ZNF518A, BLNK, PTEN, RPL13AP5, LCOR, ATAD1, FRAT2, MINPP1, PGAM1, LINC00863
# PC_ 3
# Positive:  EIF3M, DEPDC7, TCP11L1, CSTF3, CD59, FBXO3, CAPRIN1, DANCR, NAT10, SCFD2
# 	   MMADHCP2, STAM2, PRPF40A, ARL6IP6, ARL5A, NR4A2, GPD2, FAM133DP, FIP1L1, CAT
# 	   ACVR1, RIF1, NMI, MMADHC, RND3, LNX1, ELF5, LYPD6B, CASP4, CASP5
# Negative:  TLE2, TLE5, ZNF77, NCLN, ZNF57, NFIC, THOP1, SMIM24, DOHH, SGTA
# 	   MFSD12, HMG20B, APBA3, SLC39A3, MRPL54, DAPK3, GADD45B, EEF2, MAP2K2, LMNB2
# 	   SIRT6, TIMM13, YJU2, STAP2, SPPL2B, SH3GL1, CHAF1A, UBXN6, LRG1, LSM7
# PC_ 4
# Positive:  PDIA4, EZH2, ZNF212, CUL1, TPK1, ATP6V0E2, ACTR3C, ARHGEF5, LRRC61, RARRES2
# 	   EPHA1, ZYX, REPIN1, CASP2, GIMAP2, TMEM139, TMEM176B, GSTK1, TMEM176A, SSBP1
# 	   AOC1, DENND11, NOS3, AGK, MRPS33, ABCB8, NDUFB2, ADCK2, SLC4A2, MKRN1
# Negative:  YTHDC1, UGT2A3, UBA6, UGT2B7, NOA1, POLR2B, UTP3, RUFY3, REST, GRSF1
# 	   SRP72, DCK, COX18, PAICS, ANKRD17, PPAT, EXOC1, RASSF6, NMU, CXCL8
# 	   CXCL1, TMEM165, PF4, SRD5A3, PPBP, CHIC2, CXCL3, LNX1, IQANK1, CXCL2
# PC_ 5
# Positive:  CTDNEP1, ELP5, CLDN7, GABARAP, EIF5A, PHF23, DVL2, GPS2, ACADVL, C17orf49
# 	   RNASEK-C17orf49, TNK1, RNASEK, ALOX12-AS1, XAF1, TMEM256, C17orf100, CHRNB1, MED31, TXNDC17
# 	   TNFSF13, PIMREG, MIS12, EIF4A1, DERL2, RPAIN, NUP88, SPAG7, RABEP1, ZNF232
# Negative:  TMEM209, CEP41, ZC3HC1, MEST, LINC-PINT, UBE2H, MKLN1, CDC26P1, MKLN1-AS, CHCHD3
# 	   EXOC4, AHCYL2, AKR1B1, AKR1B10, TNPO3, BPGM, ATP6V1F, CYREN, CALU, CNOT4
# 	   METTL2B, HILPDA, NUP205, IMPDH1, RBM28, STMP1, SND1, ZNF800, GCC1, ARF5
#
# Computing nearest neighbor graph
#
# Computing SNN
# INFO [2023-01-12 13:12:39] define_signif_tumor_subclusters(), tumor: CRC08-PT
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  SLC46A3, SLC7A1, POMP, UBL3, URAD, HMGB1, CDX2, USPL1, PDX1, HSPH1
# 	   POLR1D, N4BP2L1, N4BP2L2, MTIF3, PDS5B, GTF3A, STARD13, RASL11A, RFC3, ALG5
# 	   RPL21, EXOSC8, USP12, SUPT20H, CDK8, UFM1, NHLRC3, RNF6, COG6, NUP58
# Negative:  HEXA, ARIH1, PARP6, BBS4, PKM, ADPGK, MYO9A, THAP10, NEO1, LRRC49
# 	   CD276, UACA, TLE3, PML, DRAIC, UBL7, RPLP1, CLK3, GLCE, EDC3
# 	   CSK, ANP32A, ULK3, CLN6, SCAMP2, CALML4, MPI, PIAS1, MAP2K5, FAM219B
# PC_ 2
# Positive:  CGGBP1, C3orf38, CHMP2B, PROS1, GBE1, NSUN3, STX19, ZNF717, RIOX2, CLDND1
# 	   LINC00960, CPOX, CMSS1, FAM86DP, TBC1D23, PPP4R2, NIT2, TFG, SHQ1, TRMT10C
# 	   RYBP, PCNP, FOXP1, ARL6IP5, ZBTB11, UBA3, RPL24, TMF1, NFKBIZ, PSMC1P1
# Negative:  GFER, NPW, NOXO1, SLC9A3R2, TBL3, NTHL1, SNHG19, TSC2, PKD1-AS1, TRAF7
# 	   SNHG9, MLST8, PGP, RPS2, E4F1, ECI1, NDUFB10, RNPS1, CCNF, MSRB1
# 	   ATP6V0C, FAHD1, AMDHD2, HAGH, PDPK1, NUBP2, SPSB3, MRPS34, NME3, JPT2
# PC_ 3
# Positive:  RARS1, PANK3, SIMC1, THOC3, KIAA1191, WWC1, RPL10P9, SFXN1, NOP16, MSX2
# 	   SPDL1, BOD1, MAT2B, HIGD2A, BNIP1, EIF4EBP3, SRA1, RANBP17, HMMR, APBB3
# 	   CCNG1, NPM1, CREBRF, ANKHD1-EIF4EBP3, CLTB, SLC35A4, ATP6V0E1, ATP10B, FBXW11, PTTG1
# Negative:  VAMP2, PER1, TMEM107, TRAPPC1, BORCS6, RPL26, NAA38, RANGRF, AURKB, WRAP53
# 	   TP53, SAT2, MPDU1, CD68, ALOX12-AS1, EIF4A1, XAF1, RNASEK, ACADVL, C17orf49
# 	   RNASEK-C17orf49, C17orf100, DVL2, MED31, TNFSF13, PHF23, TXNDC17, CHRNB1, GABARAP, PIMREG
# PC_ 4
# Positive:  SLC38A6, TRMT5, MNAT1, DHRS7, JKAMP, L3HYPDH, DAAM1, TIMM9, UBE3D, PSMA3-AS1
# 	   PGM3, ME1, PSMA3, MRAP2, AP5M1, LINC02535, TMEM260, NT5E, KTN1, FBXO34
# 	   SNX14, DLGAP5, SYNCRIP, LGALS3, SNHG5, ZNF292, MAPK1IP1L, SMIM8, SLC35A1, GCH1
# Negative:  TMEM39B, KPNA6, TXLNA, KHDRBS1, CCDC28B, PTP4A2, PEF1, IQCC, TINAGL1, SERINC2
# 	   FABP3, ZCCHC17, SNRNP40, PUM1, MECR, SRSF4, EPB41, YTHDF2, TAF12, SNHG12
# 	   TRNAU1AP, PPCS, FOXJ3, PPIH, GUCA2B, SNHG3, EDN2, YBX1, P3H1, SCMH1
# PC_ 5
# Positive:  PSMC6, ERO1A, GNPNAT1, RABGGTB, PYGL, ACADM, TMX1, RTRAF, CDKN3, CNIH1
# 	   PIGK, BMP4, CRYZ, SAV1, ZZZ3, GMFB, FPGT, ATL1, USP33, CGRRF1
# 	   ZRANB2, GCH1, DMAC2L, FUBP1, HHLA3, CTH, MAPK1IP1L, VCPKMT, ANKRD13C, DNAJB4
# Negative:  IGF2BP2, TRA2B, SENP2, LIPH, TMEM41A, TBCCD1, DNAJB11, MAP3K13, EIF4A2, EHHADH
# 	   RFC4, VPS8, ST6GAL1, MAGEF1, RTP4, EPHB3, LPP, POLR2H, CLCN2, FLJ42393
# 	   EIF4G1, P3H2, PSMD2, CLDN1, EEF1AKMT4, OPA1, ALG3, HES1, ABCF3, AP2M1
#
# Computing nearest neighbor graph
#
# Computing SNN
# INFO [2023-01-12 13:12:40] define_signif_tumor_subclusters(), tumor: CRC09-PT
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  ANGPTL4, RAB11B, RPS28, ZNF317, HNRNPM, NDUFA7, ZNF266, CD320, ZNF426, TIMM44
# 	   ZNF562, SNAPC2, ZNF846, TRAPPC5, FBXL12, STXBP2, UBL5, PET100, XAB2, PIN1
# 	   PNPLA6, MCOLN1, SHFL, PEX11G, ARHGEF18, PPAN, SH2D3A, TRIP10, GPR108, EIF3G
# Negative:  PCCB, CEP63, ANAPC13, STAG1, NCK1, DBR1, ARMC8, CEP70, FAIM, PIK3CB
# 	   MRPS22, CNIH1, GMFB, CGRRF1, CDKN3, BMP4, GCH1, GNPNAT1, MAPK1IP1L, PSMC6
# 	   COPB2, ERO1A, LGALS3, DLGAP5, RTRAF, FBXO34, TMX1, KTN1, TMEM260, RBP2
# PC_ 2
# Positive:  PARP10, GRINA, OPLAH, EXOSC4, GPAA1, CYC1, SHARPIN, MAF1, HGH1, MROH1
# 	   BOP1, HSF1, PSMC4, FBL, TIMM50, SUPT5H, RPS16, ZFP36, MED29, PAF1
# 	   PAK4, MRPS12, TECR, DNAJB1, NDUFB7, GIPC1, PKN1, SARS2, DDX39A, RAD23A
# Negative:  SMARCA5, ANAPC10, USP38, ABCE1, INPP4B, SMAD1, ZNF330, LSM6, ELMOD2, TMEM184C
# 	   SCOC, PRMT9, MGST2, LRBA, NDUFC1, ELF2, C4orf33, SCLT1, RPS3A, PGRMC2
# 	   LARP1B, SH3D19, ABHD18, GATB, MFSD8, SPRY1, ARFIP1, NUDT6, TRIM2, KIAA1109
# PC_ 3
# Positive:  FOXM1, ITFG2, RHNO1, TULP3, FKBP4, TEAD4, CRACR2A, CCND2, C12orf4, RAD51AP1
# 	   DYRK4, NDUFA9, GAU1, CD9, PLEKHG6, TNFRSF1A, SCNN1A, LTBR, CD27-AS1, TAPBPL
# 	   MRPL51, NCAPD2, GAPDH, NOP2, CHD4, LPAR5, ING4, ZNF384, COPS7A, GPS1
# Negative:  BLMH, TMIGD1, CPD, NSRP1, GOSR1, SSH2, GIT1, CRLF3, TP53I13, TEFM
# 	   ABHD15, RNF135, NUFIP2, NF1, MYO18A, RAB11FIP4, DHRS13, FLOT2, COPRS, ERAL1
# 	   FAM222B, UTP6, TRAF4, SUZ12, NEK8, TLCD1, RHOT1, RPL23A, SDF2, ZNF207
# PC_ 4
# Positive:  TDRD3, DACH1, SUGT1, OLFM4, MZT1, CKAP2, VPS36, BORA, NEK3, ALG11
# 	   DIS3, DHRS12, PIBF1, INTS6, KLF5, RNASEH2B, DLEU1, TBC1D4, TRIM13, SPRYD7
# 	   COMMD6, UCHL3, KPNA3, LMO7, EBPL, RCBTB1, CLN5, PHF11, FBXL3, SETDB2
# Negative:  MIEF2, TOP3A, FLII, SHMT1, ALKBH5, LGALS9C, CCDC144BP, DRG2, TVP23B, PRPSAP2
# 	   FAM83G, ATPAF2, B9D1, ALDH3A2, ALDH3A1, SPECC1, FKBP11, DDX23, USP22, RND1
# 	   ARF3, PRKAG1, LMBR1L, TUBA1B, TUBA1A, TUBA1C, DHRS7B, TROAP, SREBF1, VDR
# PC_ 5
# Positive:  GPRC5A, DDX47, ATL1, SAV1, DMAC2L, GPRC5D-AS1, CDKN1B, PYGL, VCPKMT, ARF6
# 	   NEMF, TMX1, HEBP1, CREBL2, RTRAF, KLHDC2, ERO1A, EMP1, PSMC6, POLE2
# 	   LINC01559, GNPNAT1, BORCS5, BMP4, ATF7IP, CDKN3, DNAAF2, STRAP, PLBD1, EPS8
# Negative:  SLC43A3, SLC43A1, SSRP1, TNKS1BP1, TIMM10, NUP160, UBE2L6, FNBP4, MTCH2, CLP1
# 	   KBTBD4, PTPMT1, NDUFS3, ZDHHC5, CELF1, PSMC3, SLC39A13, NR1H3, MED19, ACP2
# 	   DDB2, TMX2, PACSIN3, SELENOH, ARFGAP2, LPXN, CSTPP1, FAM111A, LRP4, CKAP5
#
# Computing nearest neighbor graph
#
# Computing SNN
# INFO [2023-01-12 13:12:40] define_signif_tumor_subclusters(), tumor: CRC10-PT
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  NAMPT, HBP1, COG5, SYPL1, DUS4L, ATXN7L1, BCAP29, RINT1, PUS7, CBLL1-AS1
# 	   SRPK2, CBLL1, KMT2E-AS1, DLD, KMT2E, ORC5, RCC1L, GTF2IRD2B, NSUN5P1, GTF2I
# 	   GTF2IRD1, PSMC2, LAMB1, POM121C, CCL24, DNAJC2, CLIP2, PNPLA8, RHBDD2, PMPCB
# Negative:  GAR1, PITX2, LARP7, CAMK2D, UGT8, SNHG8, METTL14, SEC24D, USP53, FABP2
# 	   ANXA5, EXOSC9, CCNA2, BBS7, KIAA1109, NUDT6, SPRY1, MFSD8, ABHD18, LARP1B
# 	   PGRMC2, SCLT1, C4orf33, ELF2, NDUFC1, MGST2, SCOC, ELMOD2, ZNF330, INPP4B
# PC_ 2
# Positive:  TRAM1, NCOA2, LACTB2, CPA6, ARFGEF1, TERF1, COPS5, CSPP1, SNHG6, RPL7
# 	   SGK3, RDH10, C8orf44, STAU2, RRS1, UBE2W, PDE7A, ELOC, MTFR1, PPP2CB
# 	   FUT10, UBXN8, RBPMS, MAK16, DCTN6, GSR, GTF2E2, LINC01605, TMEM70, ARMC1
# Negative:  CEACAM6, RPS19, ARHGEF1, CEACAM5, DMAC2, B3GNT8, RABAC1, CEACAM7, BCKDHA, EXOSC5
# 	   B9D2, ZNF574, CCDC97, DEDD2, HNRNPUL1, PAFAH1B3, CNFN, CEACAM1, CD177, LYPD3
# 	   ETHE1, XRCC1, ZNF576, PLAUR, KCNN4, ZNF224, ZNF234, PSMC4, ZNF226, ZNF227
# PC_ 3
# Positive:  CUL7, MRPL14, MRPL2, KLC4, PTK7, RRP36, CUL9, SLC29A1, MRPS18A, DNPH1
# 	   KLHDC3, MAD2L1BP, TJAP1, POLR1C, MEA1, GTPBP2, SLC35B2, XPO5, YIPF3, PPP2R5D
# 	   AARS2, CNPY3, C6orf226, CDC5L, RPL7L1, TBCC, UBR2, ENPP4, MRPS10, C6orf132
# Negative:  VWA5A, TBRG1, HSPA8, SORL1, SIAE, SC5D, OAF, TRIM29, VSIG2, RNF26
# 	   PDZD3, TMEM218, HINFP, EI24, H2AX, CHEK1, HMBS, VPS11, HYLS1, HYOU1
# 	   SLC37A4, PUS3, TRAPPC4, RPUSD4, RPS25, CENATAC, DDX6, SIAH2, MBNL1, PHLDB1
# PC_ 4
# Positive:  RHBDF1, SNRNP25, MPG, POLR3K, PSMD9, BCL7A, NPRL3, LINC02985, MLXIP, LUC7L
# 	   DIABLO, FAM234A, VPS33A, AXIN1, CLIP1, MRPL28, OGFOD2, VPS37B, RSRC2, ARL6IP4
# 	   HIP1R, DENR, PGAP6, MTRFR, NME4, CDK2AP1, DECR2, PIGQ, SBNO1, RAB40C
# Negative:  TMED7, ATG12, FEM1C, AP3S1, CCDC112, COMMD10, SEMA6A, YTHDC2, LINC00992, DCP2
# 	   HSD17B4, REEP5, SRP19, EPB41L4A-AS1, NREP, STARD4, WDR36, SLC25A46, PJA2, NUDT12
# 	   MACIR, PAM, FAM174A, CHD1, RGMB, RIOK2, ERAP2, ERAP1, CAST, GLRX
# PC_ 5
# Positive:  BAMBI, WAC, WAC-AS1, RAB18, ACBD5, MASTL, YME1L1, ABI1, ASB7, SELENOS
# 	   KIAA1217, LINS1, MSRB2, ARHGAP21, SNRPA1, PDSS1, PCSK6, THNSL1, PRTFDC1, COMMD3
# 	   DNAJC1, TM2D3, MLLT10, MEF2A, NEBL, LRRC28, ARL5B, PLEKHA1, TACC2, DMBT1
# Negative:  C6orf132, MRPS10, TAF8, CCND3, UBR2, TBCC, BYSL, RPL7L1, MED20, C6orf226
# 	   CNPY3, TOMM6, TFEB, PPP2R5D, NFYA, OARD1, MEA1, UNC5CL, KLHDC3, KCNK5
# 	   GLO1, RRP36, CCDC167, RNF8, CUL7, PIM1, KLC4, MTCH1, C6orf89, MRPL2
#
# Computing nearest neighbor graph
#
# Computing SNN
# INFO [2023-01-12 13:12:41] define_signif_tumor_subclusters(), tumor: CRC01-NT
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  LPAR2, ZNF101, PBX4, ZNF506, NDUFA13, GATAD2A, ZNF253, ZNF430, ZNF429, ZNF91
# 	   ZNF675, RPSAP58, ZNF254, ZNF83, ZNF701, ZNF880, LINC00662, LINC02987, UQCRFS1, POP4
# 	   TRIM4, AZGP1, CYP3A5, ZKSCAN1, ZNF655, ZSCAN21, FAM200A, ZNF3, ZNF394, COPS6
# Negative:  PRELID2, YIPF5, SH3RF2, ARHGAP26, SPRY4, LARS1, NDFIP1, RBM27, GNPDA1, RNF14
# 	   TCERG1, DELE1, PCDH1, SPINK1, FCHSD1, RELL2, FBXO38, HDAC3, DIAPH1, TAF7
# 	   HARS1, ZMAT2, HARS2, WDR55, IK, PCYOX1L, TMCO6, NDUFA2, CD14, SLC35A4
# PC_ 2
# Positive:  HMGB1P5, RPL15, NR1D2, SGO1, TOP2B, NGLY1, RAB5A, OXSM, TBC1D5, CMC1
# 	   OXNAD1, AZI2, DPH3, ANKRD28, BTD, TGFBR2, HACL1, STT3B, EAF1, OSBPL10
# 	   METTL6, GPD1L, CMTM8, CMTM7, CAPN7, CMTM6, RBSN, INPP1, MFSD6, HIBCH
# Negative:  RAMAC, SNHG21, C15orf40, WDR73, BTBD1, NMB, RPS17, SEC11A, UBE2Q2P2, PDE8A
# 	   EFL1, AKAP13, STARD5, KLHL25, MRPL46, MESD, MRPS11, CEMIP, AEN, FAH
# 	   ISG20, CYTOR, KRCC1, RMND5A, ZFAND6, ABHD2, FABP1, RNF103, THNSL2, CHMP3
# PC_ 3
# Positive:  CD276, NEO1, PML, ADPGK, BBS4, UBL7, ARIH1, CLK3, HEXA, PARP6
# 	   PKM, EDC3, MYO9A, THAP10, CSK, LRRC49, UACA, ULK3, TLE3, DRAIC
# 	   SCAMP2, RPLP1, GLCE, MPI, ANP32A, FAM219B, COX5A, RPP25, CLN6, PPCDC
# Negative:  NBPF1, MFAP2, NECAP2, SZRD1, ATP13A2, FBXO42, SDHB, PADI2, DCTN2, DDIT3
# 	   MARS1, OS9, RCC2, STAT6, TSPAN31, CDK4, MYO1A, PRIM1, NACA, BAZ2A
# 	   ARHGEF10L, PTGES3, METTL1, EEF1AKMT3, ALDH4A1, TSFM, AVIL, UBR4, CTDSP2, AP1B1
# PC_ 4
# Positive:  NT5E, SNX14, LINC02535, SYNCRIP, MRAP2, ME1, PGM3, UBE3D, PPAT, TPBG
# 	   ARMC10, IBTK, PAICS, FAM185A, NAPEPLD, POLR2J, TENT5A, C6orf120, PMPCB, SMOC2
# 	   SRP72, FRMD1, SFT2D1, MPC1, RPS6KA2, AFDN, UNC93A, LINC01558, LRWD1, RNASET2
# Negative:  SLC37A4, TRAPPC4, RPS25, HYOU1, CENATAC, VPS11, HMBS, H2AX, HINFP, PDZD3
# 	   RNF26, TRIM29, OAF, SC5D, SORL1, HSPA8, VWA5A, TBRG1, CD9, GAU1
# 	   NDUFA9, PLEKHG6, SCNN1A, TNFRSF1A, LTBR, DYRK4, CD27-AS1, RAD51AP1, TAPBPL, C12orf4
# PC_ 5
# Positive:  FAM214A, RSL24D1, ARPP19, PIGBOS1, MYO5C, PIGB, GNB5, MAPK6, CCPG1, ZNF280D
# 	   LEO1, TCF12, MYZAP, LYSMD2, POLR2M, ADAM10, MINDY2, USP8, SLTM, CCNB2
# 	   MYO1E, GABPB1-AS1, GCNT3, GTF2A2, GABPB1, BNIP2, SLC27A2, RPS3AP6, ANXA2, DTWD1
# Negative:  LARGE2, PEX16, CREB3L1, CRY2, MDK, AMBRA1, SLC35C1, ATG13, TP53I11, ARHGAP1
# 	   ZNF408, CD82, CKAP5, EXT2, LRP4, ACCS, CSTPP1, ARFGAP2, ALKBH3, PACSIN3
# 	   DDB2, ACP2, NR1H3, HSD17B12, ATP23, SLC39A13, PSMC3, CTDSP2, TTC17, CELF1
#
# Computing nearest neighbor graph
#
# Computing SNN
# INFO [2023-01-12 13:12:41] define_signif_tumor_subclusters(), tumor: CRC02-NT
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  NLRP2, CDC42EP5, LENG8, RPS9, TSEN34, MBOAT7, TMC4, ZNF586, LENG1, TFPT
# 	   NDUFA3, MYADM, ZNF552, ZNF331, ZNF761, ZNF816, ZNF160, ZNF468, ZNF28, TPT1
# 	   ZNF587, ZNF600, ZNF83, EDN1, RPL15P3, TBC1D7, ADTRP, SIRT5, NEDD9, TPT1-AS1
# Negative:  SRSF4, EPB41, MECR, YTHDF2, PUM1, SNRNP40, ZCCHC17, FABP3, SERINC2, HDAC1
# 	   LCK, MARCKSL1, EIF3I, TINAGL1, BSDC1, TMEM234, PEF1, ZBTB8A, IQCC, ZBTB8OS
# 	   RBBP4, CCDC28B, PTP4A2, YARS1, TXLNA, KHDRBS1, KPNA6, TMEM39B, S100PBP, TMEM54
# PC_ 2
# Positive:  TGOLN2, TMSB10, CAPG, TRABD2A, PARTICL, SUCLG1, MAT2A, GGCX, VAMP8, VAMP5
# 	   REG3A, RNF181, USP39, REG1A, C2orf68, REG1B, PTCD3, IMMT, GCFC2, MRPL35
# 	   MRPL19, EVA1A, KDM3A, TMEM42, ZDHHC3, KIF15, KIAA1143, ZNF502, POLE4, EXOSC7
# Negative:  PSMD14, TANK, GCG, DPP4, IFIH1, ITGB6, GCA, GALNT3, LY75, CERS6
# 	   MARCHF7, NOSTRIN, BAZ2B, SPC25, WDSUB1, TANC1, FASTKD1, PKP4, PPIG, ACVR1
# 	   PHOSPHO2, FAM133DP, KLHL23, GPD2, SSB, NR4A2, METTL5, ARL6IP6, PRPF40A, GORASP2
# PC_ 3
# Positive:  PMF1, SMG5, TMEM79, PMF1-BGLAP, GLMP, CCT3, SLC25A44, NAXE, SEMA4A, GPATCH4
# 	   LMNA, CRABP2, RAB25, ISG20L2, LAMTOR2, METTL25B, SSR2, HDGF, PRCC, RXFP4
# 	   IFI16, DUSP23, KHDC4, TAGLN2, IGSF9, LINC01133, IGSF8, SLC66A3, ROCK2, PDIA6
# Negative:  CLPTM1, TOMM40, RELB, NECTIN2, CLASRP, ZNF296, CBLC, GEMIN7, BCL3, TRAPPC6A
# 	   PVR, ZNF227, ERCC2, ZNF226, ZNF224, ZNF234, KCNN4, PLAUR, POLR1G, ZNF576
# 	   XRCC1, ERCC1, ETHE1, FOSB, LYPD3, VASP, CD177, FOXA3, SYMPK, PPP5C
# PC_ 4
# Positive:  RNF141, CTR9, ADM, SWAP70, EIF4G2, ZNF143, ZBED5, ZBED5-AS1, IPO7, GALNT18
# 	   TMEM41B, USP47, RPL27A, DENND2B, DENND5A, EIF3F, AKIP1, TMEM9B, MICAL2, CYB5R2
# 	   PPFIBP2, ZNF215, MRPL17, TPP1, NOP16, HIGD2A, CLTB, FAF2, RNF44, CDHR2
# Negative:  OCEL1, BABAM1, USE1, SMIM7, BLCAP, SLC35E1, CTNNBL1, TTI1, SRC, CHERP
# 	   RPRD1B, MRPL34, EPS15L1, MANBAL, TGM2, SNHG17, ACTR5, RALGAPB, AP1M1, SNHG11
# 	   DHX35, FAM32A, RPN2, HSH2D, MAFB, DDA1, RAB8A, TLDC2, TPM4, TOP1
# PC_ 5
# Positive:  YJU2B, MRI1, C19orf53, TRMT1, STX10, IER2, CC2D1A, PHB1, SPOP, UBE2Z
# 	   SNF8, IL27RA, SLC35B1, KAT7, ITGA3, MISP3, PDK2, TMEM92, ASF1B, XYLT2
# 	   MRPL27, ADGRE5, LRRC59, DDX39A, ACSF2, PKN1, RSAD1, GIPC1, EPN3, DNAJB1
# Negative:  IRF2, CDKN2AIP, CASP3, PRIMPOL, CENPU, ACSL1, SLC25A4, B9D2, BCKDHA, EXOSC5
# 	   CCDC97, HNRNPUL1, B3GNT8, CFAP97, DMAC2, SNX25, CEACAM7, CEACAM5, CEACAM6, RPS19
# 	   ARHGEF1, RABAC1, ZNF574, DEDD2, POLR1B, ZC3H8, SLC9A3R1, GPRC5C, NAT9, RPL38
#
# Computing nearest neighbor graph
#
# Computing SNN
# INFO [2023-01-12 13:12:42] define_signif_tumor_subclusters(), tumor: CRC03-NT
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  SNX25, CFAP97, SLC25A4, IPPK, SUSD3, ACSL1, NINJ1, WNK2, CENPU, PRIMPOL
# 	   CASP3, MAB21L4, GPR35, CAPN10, ANKMY1, COPS9, IRF2, RNPEPL1, NDUFA10, HES6
# 	   TCF3, CDKN2AIP, SCAMP4, ILKAP, CSNK1G2, DCTD, BTBD2, MKNK2, SCLY, AGA
# Negative:  NCOA7, HDDC2, HINT3, TPD52L1, TRMT11, SMPDL3A, PKIB, CENPW, SERINC1, RNF146
# 	   HSF2, ECHDC1, ASF1A, PTPRK, ARHGAP18, NUS1, TMEM200A, EPB41L2, GOPC, ZUP1
# 	   RWDD1, TSPYL1, NT5DC1, HDAC2, MARCKS, YRDC, CDCA8, C1orf122, C1orf109, SF3A3
# PC_ 2
# Positive:  KRR1, PHLDA1, ATXN7L3B, NAP1L1, TBC1D15, INO80C, GALNT1, ZNF24, OSBPL8, ZNF271P
# 	   C18orf21, TMEM19, RPRD1A, SLC39A6, ZNF397, PAWR, ELP2, THAP2, MAPRE2, TPGS2
# 	   ZFC3H1, PPP1R12A, RNF138, PIK3C3, PSTPIP2, CCDC59, TSPAN8, SMAD7, ATP5F1A, HAUS1
# Negative:  TMEM208, NOL3, TPPP3, KIAA0895L, ELMO3, FBXL8, E2F4, HSD11B2, TRADD, CMTM4
# 	   PHAF1, ATP6V0D1, DYNC1LI2, CKLF, CBFB, NAE1, TK2, CES3, LINC00920, CES2
# 	   CA7, SLC38A7, RPS27AP16, CTCF, CIAO2B, CNOT1, SETD6, GINS3, ACD, CDK2AP2
# PC_ 3
# Positive:  TTC33, PTGER4, PRKAA1, RPL37, FBXO4, SELENOP, ZNF131, HMGCS1, CCL28, TMEM267
# 	   PAIP1, NNT, MRPS30, PELO, ITGA2, MOCS2, NDUFS4, HSPB3, CCNO, DHX29
# 	   RPL10P9, PANK3, MTREX, SH3PXD2B, RARS1, WWC1, MAT2B, HMMR, PLPP1, DUSP1
# Negative:  KAT6A, AP3M2, IKBKB, POLB, VDAC3, ACSS1, APMAP, LINC02967, ENTPD6, CST3
# 	   SLC20A2, GZF1, ABHD12, XRN2, KIZ, SMIM19, RALGAPA2, GINS1, CRNKL1, ZNF337
# 	   NAA20, THAP1, RIN2, DTD1, SMIM26, SEC23B, RPL11, TCEA3, ID3, ELOA-AS1
# PC_ 4
# Positive:  POMZP3, DTX2, ZP3, HSPB1, MDH2, STYXL1, TMEM120A, FKBP4, RHBDD2, ITFG2
# 	   CCL24, POM121C, FOXM1, ADIRF, GLUD1, SLC7A6, WAPL, PLA2G15, CCSER2, RHNO1
# 	   SHLD2, MICU1, USP54, SEC24C, DNAJB12, CHCHD1, PPP3CB, MCU, NSUN5P1, PLA2G12B
# Negative:  SDHAF1, LIN37, PSENEN, SYNE4, ALKBH6, U2AF1L4, THAP8, COX6B1, POLR2I, RBM42
# 	   TBCB, CAPNS1, UQCRFS1, LINC02987, HAUS5, POP4, LINC00662, ZNF254, ZNF565, RPSAP58
# 	   C19orf12, ZNF675, TMEM147, ZNF91, ZNF429, ZNF146, ZNF430, URI1, ZNF253, DMKN
# PC_ 5
# Positive:  MIF4GD, MRPS7, SLC25A19, GRB2, LLGL2, GGA3, NUP85, H3-3B, ITGB4, SAP30BP
# 	   UNK, SUMO2, UNC13D, JPT1, WBP2, NT5C, TRIM47, ARMC7, SLC16A5, ATP5PD
# 	   KCTD2, MRPL38, MRPL58, SLC9A3R1, NAT9, FDXR, OTOP2, HID1, GPRC5C, ACOX1
# Negative:  PARP16, SLC51B, DPP8, MTFMT, HACD3, INTS14, SPG21, RAB11A, DIS3L, TRIP4
# 	   TIPIN, MAP2K1, PCLAF, SNAPC5, PPIB, RPL4, ZWILCH, SNX1, AAGAB, MAP2K5
# 	   CIAO2A, PIAS1, CALML4, DAPK2, CLN6, HERC1, ANP32A, USP3, GLCE, RPLP1
#
# Computing nearest neighbor graph
#
# Computing SNN
# INFO [2023-01-12 13:12:42] define_signif_tumor_subclusters(), tumor: CRC04-NT
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  TMEM52, PRKCZ, FAAP20, RER1, GNB1, PEX10, SLC35E2B, MIB2, PANK4, CDK11A
# 	   NADK, TNFRSF14-AS1, GEMIN7, SSU72, TNFRSF14, PRXL2B, TRAPPC6A, MMEL1, ARHGEF16, TPRG1L
# 	   ERCC2, ATAD3A, WRAP73, POLR1G, PLAUR, ERCC1, LRRC47, ZNF576, ATAD3B, FOSB
# Negative:  FZD6, SLC25A32, DCAF13, ATP5MC3, LNPK, ATF2, OXR1, H3P6, HOXD1, SCRN3
# 	   CIR1, OLA1, MTX2, SP3, CDCA7, HNRNPA3, EIF3E, MAP3K20, UBR5-DT, NFE2L2
# 	   ITGA6, AGPS, METAP1D, EMC2, RBM45, LRATD1, LNX1, PRKRA, FIP1L1, CHIC2
# PC_ 2
# Positive:  IL1B, IL1RN, BUB1, MIR4435-2HG, SLC20A1, MTLN, PAX8-AS1, NPHP1, BCL2L11, CHCHD5
# 	   CBWD2, POLR1B, MALL, RABL2A, ZC3H8, ANAPC1, TMEM87B, SLC35F5, SOWAHC, DDX18
# 	   SEPTIN10, CCDC93, CCDC138, INSIG2, STEAP3, RANBP2, C2orf76, GCC2, DBI, SULT1C2
# Negative:  MGME1, OVOL2, SNX5, KAT14, RRBP1, DSTN, SNRPB2, PET117, KIF16B, NDUFAF5
# 	   ESF1, ZNF133, TASP1, BTBD3, JAG1, POLR3F, SLX4IP, MKKS, PLCB4, SEC23B
# 	   TMX4, FERMT1, CRLS1, SMIM26, TRMT6, SHLD1, GPCPD1, PCNA, TMEM230, DTD1
# PC_ 3
# Positive:  PTS, SDHD, IL18, TIMM8B, TTC12, NKAPD1, TMPRSS5, C11orf52, DLAT, CRYAB
# 	   ZW10, C11orf1, USP28, C11orf71, FDXACB1, ALG9, RBM7, PPP2R1B, REXO2, COLCA2
# 	   SPATS2L, FDX1, KCTD18, NXPE4, AASDHPPT, MAIP1, DDX10, SGO2, NXPE2, POGLUT3
# Negative:  ECSIT, CDKN2D, PRKCSH, ELOF1, ZNF627, AP1M2, SLC44A2, SWSAP1, ILF3-DT, KRI1
# 	   SMARCA4, ACP5, CCDC159, ATG4D, LDLR, TIMM29, ILF3, YIPF2, KEAP1, TMED1
# 	   CDC37, TMEM205, ZNF823, DOCK6, QTRT1, DNM2, ZNF69, TYK2, RAB3D, ICAM3
# PC_ 4
# Positive:  NEO1, CD276, PML, ADPGK, UBL7, BBS4, ARIH1, CLK3, HEXA, EDC3
# 	   PARP6, PKM, MYO9A, THAP10, LRRC49, CSK, UACA, TLE3, DRAIC, RPLP1
# 	   ULK3, GLCE, SCAMP2, MPI, ANP32A, FAM219B, COX5A, CLN6, RPP25, CALML4
# Negative:  SNX16, E2F5, RBIS, CA1, CA2, RMDN1, CPNE3, SLC25A44, PMF1-BGLAP, OSGIN2
# 	   PMF1, SMG5, ACIN1, C14orf119, NBN, BCL2L2-PABPN1, BCL2L2, PABPN1, NGDN, THTPA
# 	   AP1G2, TMEM79, DHRS4-AS1, DHRS4, DECR1, GLMP, DHRS4L2, SHARPIN, MAF1, PCK2
# PC_ 5
# Positive:  BAZ1B, BCL7B, TBL2, MLXIPL, BUD23, ABHD11-AS1, ABHD11, CLDN3, CLDN4, METTL27
# 	   ELN-AS1, EIF4H, RFC2, CLIP2, GTF2IRD1, H2BC15, H3C12, GTF2I, H2AC17, ZNF165
# 	   TTC13, ARV1, C1orf131, GNPAT, ZSCAN16, ZSCAN9, SPRTN, RCC1L, ZSCAN26, EGLN1
# Negative:  MIF, DDT, SLC2A11, CABIN1, SPECC1L, GUCD1, SNRPD3, LRRC75B, GGT1, LHFPL7
# 	   CRYBB2P1, HPS4, TFIP11, TFIP11-DT, TPST2, PITPNB, TTC28-AS1, CHEK2, HSCB, NDUFAB1
# 	   CCDC117, PGRMC2, LARP1B, DCTN5, SCLT1, ABHD18, MFSD8, PLK1, C4orf33, XBP1
#
# Computing nearest neighbor graph
#
# Computing SNN
# INFO [2023-01-12 13:12:42] define_signif_tumor_subclusters(), tumor: CRC05-NT
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  RBBP4, S100PBP, YARS1, TMEM54, AK2, ZBTB8OS, AZIN2, ZBTB8A, PHC2, SMIM12
# 	   BSDC1, GJB4, MARCKSL1, GJB3, HDAC1, TMEM35B, LCK, EIF3I, ZMYM6, TMEM234
# 	   IQCC, CCDC28B, SFPQ, TXLNA, KIAA0319L, KPNA6, PSMB2, TMEM39B, KHDRBS1, AGO3
# Negative:  ZNF83, ZNF701, ZNF880, ZNF480, ZNF766, ZNF350, ZNF649, ZNF577, ETFB, KLK12
# 	   KLK11, KLK10, KLK8, KLK7, FLJ42393, LPP, KLK6, RTP4, KLK1, ST6GAL1
# 	   C19orf48, RFC4, JOSD2, EIF4A2, PCID2, EMC10, F10, ATAD3B, MCF2L, ATAD3A
# PC_ 2
# Positive:  TMEM123, MMP7, BIRC2, MMP1, DCUN1D5, BIRC3, CASP4, CASP5, JRKL, CASP1
# 	   CARD16, AASDHPPT, CWF19L2, CCDC82, SLC35F2, CUL5, MTMR2, ACAT1, CEP57, POGLUT3
# 	   ENDOD1, DDX10, FDX1, COLCA2, PPP2R1B, ALG9, FDXACB1, C11orf1, CRYAB, C11orf52
# Negative:  MRPL45, NPEPPSP1, HNF1B, CDK12, PPP1R1B, STARD3, PGAP3, ERBB2, MIEN1, GRB7
# 	   GSDMB, MAP3K13, LIPH, TMEM41A, IGF2BP2, SENP2, EHHADH, TRA2B, VPS8, CLCN2
# 	   EIF4G1, POLR2H, MAGEF1, PSMD2, TBCCD1, EPHB3, EEF1AKMT4, ALG3, DNAJB11, ABCF3
# PC_ 3
# Positive:  TNFRSF21, MEP1A, CD2AP-DT, CYP39A1, CD2AP, MMUT, ENPP5, CENPQ, C6orf141, ENPP4
# 	   MCM3, CDC5L, AARS2, PAQR8, EFHC1, SLC35B2, TMEM14A, SLC29A1, GSTA1, MRPL14
# 	   GSTA4, 7SK, MRPS18A, FBXO9, ELOVL5, MAD2L1BP, GCLC, LRRC1, GTPBP2, TINAG
# Negative:  TMEM263, RIC8B, C12orf75, MTERF2, APPL2, WASHC4, NOPCHAP1, RPL18AP3, TXNRD1, NFYB
# 	   TDG, C12orf73, ISCU, HSP90B1, CORO1C, PARPBP, HHLA3, NUP37, USP30, CTH
# 	   ZRANB2, WASHC3, FPGT, CRYZ, GNPTAB, ACADM, CRYAB, C11orf1, C11orf52, DLAT
# PC_ 4
# Positive:  H2BC15, H3C12, H2AC17, SIRT5, TBC1D7, NOL7, RPL15P3, SH3GL1, ZNF165, MCUR1
# 	   EDN1, GMPR, CD83, MYLIP, ADTRP, ZSCAN16, DTNBP1, NEDD9, STAP2, TMEM14B
# 	   TMEM14C, ZSCAN9, PAK1IP1, HULC, YJU2, SLC35B3, SIRT6, ZSCAN26, MAP2K2, EEF2
# Negative:  RFC5, FBXO21, TESC, WSB2, SPRING1, VSIG10, PEBP1, MED13L, TAOK3, TBX3
# 	   SUDS3, PRKAB1, RBM19, RAB35, GCN1, RPLP0, SDSL, COX6A1, TRIAP1, GATC
# 	   SLC8B1, SRSF9, DYNLL1, TPCN1, NRAV, COQ5, RITA1, RNF10, POP5, DDX54
# PC_ 5
# Positive:  C6orf120, OSBPL5, ZNF195, RHOG, NUP98, PGAP2, STIM1, RRM1, TRIM21, GLMN
# 	   BNIP2, TRIM68, EPHX4, EVI5, RPS3AP6, TRIM34, ZNF644, GTF2A2, ANXA2, VPS13C
# 	   TRIM5, TPM1, USP3, RPL5, CA12, GCNT3, ZNF326, LACTB, RPS27L, FHIP1B
# Negative:  NUP42, MALSU1, TOMM7, CDCA7L, KLHL7, TRA2A, ITGB8-AS1, CCDC126, MACC1-DT, FAM221A
# 	   MACC1, OSBPL3, POLR1F, CYCS, SNX13, NFE2L3, AGR3, HNRNPA2B1, AGR2, BZW2
# 	   CBX3, ANKMY2, SKAP2, HOTAIRM1, HOXA5, SOSTDC1, HOXA6, HOXA7, ARL4A, HOXA9
#
# Computing nearest neighbor graph
#
# Computing SNN
# INFO [2023-01-12 13:12:43] define_signif_tumor_subclusters(), tumor: CRC07-NT
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  NDUFA5, WASL, WASL-DT, FAM3C, POT1, ING3, GRM8, TSPAN12, LSM8, CFTR
# 	   ST7, CAPZA2, MET, TES, SMIM30, TMEM168, IFRD1, ZNF277, DNAJB9, PNPLA8
# 	   SF3B1, COQ10B, HSPD1, LAMB1, GTF3C3, SLC39A10, STK17B, HSPE1, NABP1, MOB4
# Negative:  DOLPP1, CRAT, PTPA, LINC00963, NTMT1, ASB6, PTGES, TOR1B, TOR1A, C9orf78
# 	   USP20, ASS1, FUBP3, EXOSC2, ABL1, NUP214, POMT1, UCK1, MED27, SETX
# 	   TTF1, GOSR2, DDX31, SPIB, POLD1, CDC27, NR1H2, GARIN5A, MYH14, VRK3
# PC_ 2
# Positive:  NR1H3, ACP2, SLC39A13, PSMC3, CELF1, NDUFS3, PTPMT1, KBTBD4, MTCH2, FNBP4
# 	   DMAP1, ERI3, CCDC24, TMEM53, KIF2C, RPS8, B4GALT2, PLK3, NUP160, ATP6V0B
# 	   EIF2B3, DPH2, HECTD3, PTPRF, TNKS1BP1, UROD, HPDL, HYI, MUTYH, SSRP1
# Negative:  GBA, SCAMP3, MTX1, FDPS, THBS3, RUSC1, MUC1, ASH1L, MSTO1, KRTCAP2
# 	   YY1AP1, DAP3, GON4L, DPM3, KHDC4, RXFP4, SSR2, SLC50A1, LAMTOR2, RAB25
# 	   LMNA, EFNA1, SEMA4A, MEF2A, PRC1, LINS1, SLCO3A1, RCCD1, LRRC28, MCTP2
# PC_ 3
# Positive:  RPL6, HECTD4, TRAFD1, PTPN11, NAA25, OAS1, BRAP, ERP29, ATXN2, ACAD10
# 	   TMEM116, MAPKAPK5, MAPKAPK5-AS1, OAS3, PPP1CC, RASAL1, TCTN1, VPS29, DDX54, GPN3
# 	   RITA1, ARPC3, TPCN1, ANAPC7, SLC8B1, SDSL, LRRC57, IFT81, HAUS2, RBM19
# Negative:  MAT2A, GGCX, VAMP8, VAMP5, RNF181, USP39, C2orf68, PTCD3, IMMT, MRPL35
# 	   KDM3A, CHMP3, RNF103, RMND5A, CYTOR, KRCC1, FABP1, THNSL2, EIF2AK3, RPIA
# 	   IGKC, TMEM127, PRKAG1, LMBR1L, FKBP11, ARF3, ECHDC2, RND1, DDX23, SCP2
# PC_ 4
# Positive:  ENTPD6, ACSS1, APMAP, ABHD12, GINS1, ZNF337, HM13, LINC02967, MCTS2, ID1
# 	   BCL2L1, CST3, TPX2, PDRG1, GZF1, ACADSB, OAT, TM9SF4, XRN2, LHPP
# 	   PLAGL2, EEF1AKMT2, KIZ, POFUT1, ABRAXAS2, PXMP4, KIF3B, ACTL10, RALGAPA2, NOL4L
# Negative:  CCPG1, PIGB, ZNF280D, PIGBOS1, TCF12, RSL24D1, FAM214A, MYZAP, ARPP19, SNAP47
# 	   JMJD4, ARF1, CDC42BPA, POLR2M, COQ8A, MYO5C, C1orf35, PSEN2, PARP1, ACBD3
# 	   MRPL55, ADAM10, GNB5, SDE2, GUK1, PYCR2, TRIM11, MAPK6, LEFTY1, MINDY2
# PC_ 5
# Positive:  DNAJB11, EIF4A2, RFC4, ST6GAL1, RTP4, FLJ42393, LPP, P3H2, CLDN1, OPA1
# 	   HES1, TMEM44-AS1, TMEM44, LSG1, FAM43A, ACAP2, PPP1R2, MUC20P1, MUC20-OT1, MUC20
# 	   MUC4, TFRC, PCYT1A, DYNLT2B, REEP4, RNF168, WDR53, PIGX, PAK2, BMP1
# Negative:  ACIN1, C14orf119, BCL2L2, BCL2L2-PABPN1, RANBP2, GCC2, C2orf49, SULT1C2, CCDC138, TGFBRAP1
# 	   FHL2, NCK2, UXS1, TXNDC9, NPAS2, EIF5B, MRPS9, RPL31, SEPTIN10, TMEM182
# 	   PDCL3, MFSD9, REV1, MRPL30, CNOT11, RUFY1, ZNF354A, RNF149, SLC9A2, PABPN1
#
# Computing nearest neighbor graph
#
# Computing SNN
# INFO [2023-01-12 13:12:43] define_signif_tumor_subclusters(), tumor: CRC08-NT
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  F3, SLC44A3-AS1, SLC44A3, CNN3, ALG14, TLCD4, SNX7, SLC35A3, RPL7P9, RWDD3
# 	   TRMT13, DBT, RTCA, EXTL2, SLC30A7, DPH5, DPH5-DT, RNPC3, AMY2B, PRMT6
# 	   VAV3, SLC25A24, STXBP3, PRPF38B, HENMT1, GPSM2, CLCC1, TAF13, TMEM167B, SARS1
# Negative:  ATG13, AMBRA1, MDK, CREB3L1, MSRB1, NDUFB10, RPS2, FAHD1, HAGH, SNHG9
# 	   NUBP2, JPT2, TBL3, CLCN7, SPSB3, NME3, LARGE2, C16orf91, MRPS34, GNPTG
# 	   NOXO1, TSR3, UBE2I, TPSG1, PEX16, LMF1, GFER, CHTF18, RPUSD1, SNRNP25
# PC_ 2
# Positive:  ATG4D, KRI1, KEAP1, CDKN2D, SLC44A2, AP1M2, CDC37, ILF3-DT, TYK2, ILF3
# 	   ICAM3, QTRT1, RAVER1, DNM2, FDX2, TMED1, ICAM1, YIPF2, TIMM29, SMARCA4
# 	   ZNF627, ACP5, LDLR, ELOF1, ZNF823, ZNF69, ECSIT, DOCK6, PRKCSH, ZNF700
# Negative:  ANXA2, TPM1, VPS13C, LACTB, CIAO2A, RPS27L, DAPK2, SNX1, CA12, USP3
# 	   HERC1, RPS3AP6, KCNE3, POLD3, LIPT2-AS1, PPIB, SLCO2B1, BNIP2, PGM2L1, ARRB1
# 	   GTF2A2, GCNT3, UCP2, RPS3, KLHL35, MYO1E, GDPD5, SERPINH1, PAAF1, CCNB2
# PC_ 3
# Positive:  CPSF7, TMEM138, TMEM216, CYB561A3, SDHAF2, TKFC, TMEM258, DDB1, FEN1, VPS37C
# 	   FTH1, ASRGL1, TMEM109, AHNAK, MS4A8, EEF1G, TUT1, MS4A12, MTA2, MRPL16
# 	   B3GAT3, STX3, TGM2, INTS5, OSBP, RPRD1B, C11orf98, FAM111A, TTI1, LPXN
# Negative:  PPP1R14D, ZFYVE19, RAD51, RMDN3, RAD51-AS1, DNAJC17, SPINT1-AS1, GCHFR, RPUSD2, CCDC32
# 	   IVD, SPINT1, DPH6, PHGR1, THBS1, EIF2AK4, SRP14, ZNF770, RHOV, DLL4
# 	   CHAC1, INO80, OIP5-AS1, OIP5, NUSAP1, NDUFAF1, RTF1, MGA, JMJD7, JMJD7-PLA2G4B
# PC_ 4
# Positive:  SRSF8, CWC15, FUT4, ENDOD1, PIWIL4, CEP57, ANKRD49, MTMR2, MRE11, PANX1
# 	   CCDC82, MED17, C11orf54, JRKL, TAF1D, BIRC3, SMCO4, CHORDC1, CTSC, PRSS23
# 	   TFB1M, SCAF8, SNX9, TMEM242, ARID1B, SYNJ2, GTF2H5, TULP4, FBXO5, ME3
# Negative:  TBC1D5, RAB5A, OXNAD1, DPH3, SGO1, ANKRD28, EEF1AKMT4, ALG3, HMGB1P5, PSMD2
# 	   BTD, ABCF3, RO60, GLRX2, CMTM6, UCHL5, CMTM7, EIF4G1, CDC73, AP2M1
# 	   DYNC1LI1, RGS2, RPL15, HACL1, CNOT10, DENND1B, CMTM8, TPR, CLCN2, EIF2B5
# PC_ 5
# Positive:  ACOX1, TEN1, CDK3, MRPL38, EVPL, SRP68, RNF157, EXOC7, TRIM47, PRPSAP1
# 	   UBE2O, WBP2, UNC13D, RHBDF2, SNHG16, UNK, TTC13, ARV1, C1orf198, ST6GALNAC1
# 	   CAPN9, SNAI1, AGT, JMJD6, C1orf131, COG2, RNF114, METTL23, H3-3B, GALNT2
# Negative:  CINP, MOK, WDR20, HSP90AA1, DYNC1H1, PPP2R5C, DIO3OS, DHX9, RGS16, GLUL
# 	   IER5, LAMC2, STX6, WDR25, ACBD6, SMG7, WARS1, ARPC5, SLC25A29, TSEN15
# 	   YY1, C1orf21, DEGS2, CCNK, SETD3, RPL3P4, EDEM3, VRK1, PAPOLA, UCA1
#
# Computing nearest neighbor graph
#
# ...
# chr20-region_126 : 5  (P= 0.164024077589857 ) ->  3 (P= 0.399455662075921 )
# chr2-region_141 : 4  (P= 0.266177667713575 ) ->  3 (P= 0.462478039182041 )
# chr2-region_143 : 4  (P= 0.385551176699748 ) ->  5 (P= 0.395261486464336 )
# chr5-region_154 : 5  (P= 0.326590269570057 ) ->  4 (P= 0.501866801168479 )
# chr6-region_158 : 5  (P= 0.285771627510876 ) ->  4 (P= 0.494640173459888 )
# chr11-region_177 : 5  (P= 0.342306128541611 ) ->  4 (P= 0.347959034415284 )
# chr11-region_182 : 4  (P= 0.250087342081016 ) ->  5 (P= 0.432977583003499 )
# chr11-region_183 : 5  (P= 0.320773691159196 ) ->  6 (P= 0.355995193559902 )
# chr12-region_186 : 5  (P= 0.308397788424196 ) ->  4 (P= 0.315110428255861 )
# chr17-region_198 : 5  (P= 0.107626176343073 ) ->  4 (P= 0.617641100266258 )
# chr19-region_202 : 4  (P= 0.275540987094237 ) ->  3 (P= 0.429640937976356 )
# chr8-region_256 : 5  (P= 0.337579924315486 ) ->  4 (P= 0.393921195223509 )
# chr10-region_262 : 2  (P= 0.144052626780464 ) ->  3 (P= 0.285941234395278 )
# chr17-region_277 : 4  (P= 0.376182988909932 ) ->  3 (P= 0.402619114094915 )
# chr17-region_280 : 5  (P= 0.24274581802745 ) ->  4 (P= 0.517745758804917 )
# chr17-region_336 : 5  (P= 0.199929827447836 ) ->  4 (P= 0.58339794101138 )
# chr1-region_351 : 4  (P= 0.144921006352438 ) ->  5 (P= 0.288167825937142 )
# chr1-region_353 : 2  (P= 0.141123962027101 ) ->  3 (P= 0.287180163777304 )
# chr3-region_357 : 4  (P= 0.149996988120432 ) ->  5 (P= 0.28342659633607 )
# chr4-region_360 : 2  (P= 0.144841215577255 ) ->  1 (P= 0.286014641982684 )
# chr6-region_367 : 4  (P= 0.143624600268007 ) ->  3 (P= 0.286128314656982 )
# chr6-region_368 : 5  (P= 0.143750517377457 ) ->  4 (P= 0.287132341680253 )
# chr7-region_370 : 4  (P= 0.143885289088534 ) ->  5 (P= 0.283968628441753 )
# chr8-region_371 : 2  (P= 0.143245409141396 ) ->  1 (P= 0.282871542150439 )
# chr10-region_379 : 2  (P= 0.145237202426344 ) ->  3 (P= 0.284304365725719 )
# chr12-region_385 : 4  (P= 0.145086924124916 ) ->  6 (P= 0.282990444898363 )
# chr12-region_386 : 5  (P= 0.143963476128694 ) ->  6 (P= 0.282990444898363 )
# chr13-region_388 : 6  (P= 0.141736433594425 ) ->  5 (P= 0.289282566189409 )
# chr13-region_389 : 5  (P= 0.141659651855957 ) ->  4 (P= 0.289536425876018 )
# chr14-region_391 : 4  (P= 0.143356922571684 ) ->  6 (P= 0.285043706848761 )
# chr16-region_396 : 2  (P= 0.142533008769527 ) ->  1 (P= 0.285640556300701 )
# chr17-region_402 : 4  (P= 0.145158613690665 ) ->  5 (P= 0.283677091369287 )
# chr19-region_408 : 2  (P= 0.141182533627919 ) ->  1 (P= 0.283713620267229 )
# chr21-region_411 : 4  (P= 0.146602543696618 ) ->  3 (P= 0.280857295497803 )
# chr19-region_433 : 4  (P= 0.213733143321303 ) ->  3 (P= 0.473817454989331 )
# chr1-region_444 : 4  (P= 0.220859408300927 ) ->  3 (P= 0.4928817679945 )
# chr6-region_455 : 5  (P= 0.267355255043484 ) ->  3 (P= 0.457496666919374 )
# chr7-region_457 : 5  (P= 0.286940845615611 ) ->  4 (P= 0.392252376349335 )
# chr8-region_463 : 4  (P= 0.356867034640517 ) ->  3 (P= 0.394639721361247 )
# chr8-region_464 : 5  (P= 0.320535586623038 ) ->  3 (P= 0.344563323183193 )
# chr11-region_472 : 4  (P= 0.294811554433551 ) ->  3 (P= 0.48997765515903 )
# chr13-region_478 : 5  (P= 0.29847309892537 ) ->  6 (P= 0.442390969346195 )
# chr16-region_481 : 5  (P= 0.212140695066256 ) ->  4 (P= 0.321820443968898 )
# chr19-region_488 : 5  (P= 0.175545539054293 ) ->  6 (P= 0.432089735651725 )
# chr19-region_491 : 4  (P= 0.285694251495385 ) ->  5 (P= 0.31897145778004 )
# chr20-region_493 : 4  (P= 0.215432228593029 ) ->  5 (P= 0.4084276858783 )
# chr22-region_496 : 2  (P= 0.252093685166733 ) ->  3 (P= 0.462691178920855 )
# chr6-region_516 : 5  (P= 0.33338887532658 ) ->  4 (P= 0.359738374217241 )
# chr7-region_519 : 5  (P= 0.346498772484157 ) ->  4 (P= 0.365579789291112 )
# chr8-region_525 : 4  (P= 0.288878171882235 ) ->  3 (P= 0.403729337783611 )
# chr11-region_538 : 4  (P= 0.313745666293453 ) ->  5 (P= 0.343574863064634 )
# chr13-region_544 : 5  (P= 0.309747727507166 ) ->  6 (P= 0.458151315836803 )
# chr16-region_549 : 4  (P= 0.291945181024857 ) ->  3 (P= 0.455279809443347 )
# chr18-region_556 : 2  (P= 0.454139734339241 ) ->  3 (P= 0.468560563473382 )
# chr19-region_561 : 4  (P= 0.422377158217839 ) ->  3 (P= 0.45914067772022 )
# chr21-region_569 : 4  (P= 0.327669268562787 ) ->  3 (P= 0.422664721402515 )
# chr3-region_581 : 4  (P= 0.380398074536611 ) ->  3 (P= 0.473835846519697 )
# chr6-region_590 : 5  (P= 0.338829582684486 ) ->  4 (P= 0.444775526879744 )
# chr11-region_605 : 5  (P= 0.297837400622701 ) ->  4 (P= 0.455637304021699 )
# chr13-region_614 : 5  (P= 0.35354785408802 ) ->  6 (P= 0.365775254632304 )
# chr17-region_619 : 2  (P= 0.42117336710577 ) ->  3 (P= 0.421778045167869 )
# chr21-region_633 : 4  (P= 0.382893040477991 ) ->  3 (P= 0.433231377077676 )
# chr6-region_650 : 5  (P= 0.142558818355678 ) ->  4 (P= 0.286744097572548 )
# chr6-region_651 : 4  (P= 0.143139470262915 ) ->  3 (P= 0.286304957149806 )
# chr8-region_657 : 4  (P= 0.19839288738 ) ->  3 (P= 0.2380652902603 )
# chr11-region_663 : 4  (P= 0.145354822996911 ) ->  3 (P= 0.28473137076702 )
# chr11-region_664 : 5  (P= 0.146295750561606 ) ->  4 (P= 0.28320828778902 )
# chr17-region_679 : 2  (P= 0.142517189992331 ) ->  3 (P= 0.286314882998807 )
# chr17-region_681 : 4  (P= 0.143005328690353 ) ->  3 (P= 0.285841435453187 )
# chr17-region_682 : 5  (P= 0.141118465326263 ) ->  2 (P= 0.286669592200666 )
# chr17-region_683 : 4  (P= 0.143005328690353 ) ->  3 (P= 0.285841435453187 )
# chr17-region_684 : 5  (P= 0.141721270153001 ) ->  6 (P= 0.288609208193186 )
# chr20-region_688 : 4  (P= 0.141781568777529 ) ->  3 (P= 0.286882024632973 )
# chr20-region_689 : 5  (P= 0.140729695727098 ) ->  3 (P= 0.250605177320127 )
# chr7-region_702 : 5  (P= 0.169172411680255 ) ->  3 (P= 0.400952314915665 )
# chr7-region_703 : 4  (P= 0.3365464788509 ) ->  3 (P= 0.468973679406638 )
# chr7-region_704 : 5  (P= 0.375857119590922 ) ->  4 (P= 0.385765139518552 )
# chr7-region_706 : 5  (P= 0.26544833396052 ) ->  4 (P= 0.329550301410326 )
# chr8-region_713 : 5  (P= 0.215053655485074 ) ->  4 (P= 0.354863861303716 )
# chr8-region_714 : 6  (P= 0.247767563256705 ) ->  4 (P= 0.340930344044568 )
# chr8-region_716 : 6  (P= 0.269195480940608 ) ->  5 (P= 0.43028300157874 )
# chr17-region_730 : 2  (P= 0.367505880299499 ) ->  3 (P= 0.382723332622241 )
# chr20-region_738 : 4  (P= 0.139786511551436 ) ->  6 (P= 0.28539103510774 )
# chr1-region_743 : 4  (P= 0.333467799814311 ) ->  3 (P= 0.366590375822585 )
# chr3-region_749 : 4  (P= 0.170378442655056 ) ->  3 (P= 0.364265247529456 )
# chr3-region_750 : 5  (P= 0.310139687713787 ) ->  4 (P= 0.38771686795002 )
# chr7-region_758 : 4  (P= 0.28231740252338 ) ->  6 (P= 0.301281775963034 )
# chr7-region_759 : 5  (P= 0.292950812876081 ) ->  6 (P= 0.407414215904614 )
# chr7-region_761 : 5  (P= 0.172704367719323 ) ->  6 (P= 0.563248648072612 )
# chr8-region_768 : 6  (P= 0.332766074129976 ) ->  5 (P= 0.465549675596789 )
# chr10-region_771 : 2  (P= 0.142849744277045 ) ->  3 (P= 0.28503824823516 )
# chr13-region_776 : 5  (P= 0.258967420258704 ) ->  6 (P= 0.507629321890144 )
# chr14-region_777 : 5  (P= 0.168051587361055 ) ->  6 (P= 0.464991685856847 )
# chr14-region_778 : 4  (P= 0.16622296673473 ) ->  6 (P= 0.399341896571813 )
# chr20-region_792 : 5  (P= 0.197083186848755 ) ->  6 (P= 0.501062059011051 )
# chr1-region_798 : 4  (P= 0.366186529818779 ) ->  3 (P= 0.429693897738414 )
# chr8-region_807 : 4  (P= 0.239011079597178 ) ->  5 (P= 0.416107323784615 )
# chr17-region_821 : 5  (P= 0.294128381316847 ) ->  4 (P= 0.297636918335303 )
# chr19-region_828 : 4  (P= 0.27097720462238 ) ->  3 (P= 0.354590804664627 )
# chr20-region_834 : 5  (P= 0.169340390784158 ) ->  3 (P= 0.451230327929589 )
# chr20-region_835 : 6  (P= 0.297664127173293 ) ->  5 (P= 0.298483516143993 )
# chr20-region_836 : 5  (P= 0.332364335450202 ) ->  6 (P= 0.39050478027288 )
# chr8-region_859 : 5  (P= 0.357406327524162 ) ->  6 (P= 0.424219464896409 )
# chr17-region_880 : 4  (P= 0.166794943712846 ) ->  3 (P= 0.462688708912108 )
# chr17-region_881 : 5  (P= 0.187097328270755 ) ->  4 (P= 0.309778507111134 )
# chr17-region_882 : 4  (P= 0.381390213811461 ) ->  3 (P= 0.41684492132817 )
# chr20-region_888 : 5  (P= 0.234737170952826 ) ->  4 (P= 0.419693314474868 )
# chr20-region_889 : 6  (P= 0.356012476806575 ) ->  5 (P= 0.456152457231254 )
# chr1-region_897 : 4  (P= 0.309213994024343 ) ->  3 (P= 0.438028731576746 )
# chr1-region_907 : 4  (P= 0.378451459414895 ) ->  3 (P= 0.383749830988291 )
# chr2-region_916 : 5  (P= 0.273640911058079 ) ->  4 (P= 0.387349813714556 )
# chr2-region_917 : 4  (P= 0.293632730739303 ) ->  3 (P= 0.440845299471699 )
# chr6-region_931 : 4  (P= 0.222262687788272 ) ->  3 (P= 0.421586830976059 )
# chr7-region_934 : 4  (P= 0.234259782864291 ) ->  5 (P= 0.410283989607112 )
# chr8-region_937 : 4  (P= 0.292338970256118 ) ->  5 (P= 0.293521942776041 )
# chr8-region_938 : 5  (P= 0.193701303049591 ) ->  6 (P= 0.594797677031284 )
# chr10-region_942 : 2  (P= 0.336220555144174 ) ->  3 (P= 0.418914969784674 )
# chr11-region_948 : 4  (P= 0.288001674169046 ) ->  5 (P= 0.315121238709879 )
# chr11-region_952 : 4  (P= 0.348940769252418 ) ->  3 (P= 0.479171490829998 )
# chr13-region_1073 : 2  (P= 0.294917799437576 ) ->  3 (P= 0.432172246103964 )
# chr8-region_1115 : 2  (P= 0.164557127993095 ) ->  3 (P= 0.44384154829689 )
# INFO [2023-01-12 13:45:04] Creating Plots for CNV and cell Probabilities.
# INFO [2023-01-12 13:48:38] ::plot_cnv:Start
# INFO [2023-01-12 13:48:38] ::plot_cnv:Current data dimensions (r,c)=8222,1395 Total=1668693.28475838 Min=0 Max=0.992432558477474.
# INFO [2023-01-12 13:48:39] ::plot_cnv:Depending on the size of the matrix this may take a moment.
# INFO [2023-01-12 13:48:39] plot_cnv_observation:Start
# INFO [2023-01-12 13:48:39] Observation data size: Cells= 1097 Genes= 8222
# INFO [2023-01-12 13:48:39] plot_cnv_observation:Writing observation groupings/color.
# INFO [2023-01-12 13:48:39] plot_cnv_observation:Done writing observation groupings/color.
# INFO [2023-01-12 13:48:39] plot_cnv_observation:Writing observation heatmap thresholds.
# INFO [2023-01-12 13:48:39] plot_cnv_observation:Done writing observation heatmap thresholds.
# INFO [2023-01-12 13:48:41] Colors for breaks:  #00008B,#24249B,#4848AB,#6D6DBC,#9191CC,#B6B6DD,#DADAEE,#FFFFFF,#EEDADA,#DDB6B6,#CC9191,#BC6D6D,#AB4848,#9B2424,#8B0000
# INFO [2023-01-12 13:48:41] Quantiles of plotted data range: 0,0,0,0,0.992432558477474
# INFO [2023-01-12 13:48:42] plot_cnv_references:Start
# INFO [2023-01-12 13:48:42] Reference data size: Cells= 298 Genes= 8222
# INFO [2023-01-12 13:48:42] plot_cnv_references:Number reference groups= 9
# INFO [2023-01-12 13:48:42] plot_cnv_references:Plotting heatmap.
# INFO [2023-01-12 13:48:43] Colors for breaks:  #00008B,#24249B,#4848AB,#6D6DBC,#9191CC,#B6B6DD,#DADAEE,#FFFFFF,#EEDADA,#DDB6B6,#CC9191,#BC6D6D,#AB4848,#9B2424,#8B0000
# INFO [2023-01-12 13:48:43] Quantiles of plotted data range: 0,0,0,0,0.567827753896036
# INFO [2023-01-12 13:48:54] ::plot_cnv:Start
# INFO [2023-01-12 13:48:54] ::plot_cnv:Current data dimensions (r,c)=8222,1395 Total=35977201 Min=1 Max=6.
# INFO [2023-01-12 13:48:54] ::plot_cnv:Depending on the size of the matrix this may take a moment.
# INFO [2023-01-12 13:48:55] plot_cnv_observation:Start
# INFO [2023-01-12 13:48:55] Observation data size: Cells= 1097 Genes= 8222
# INFO [2023-01-12 13:48:55] plot_cnv_observation:Writing observation groupings/color.
# INFO [2023-01-12 13:48:55] plot_cnv_observation:Done writing observation groupings/color.
# INFO [2023-01-12 13:48:55] plot_cnv_observation:Writing observation heatmap thresholds.
# INFO [2023-01-12 13:48:55] plot_cnv_observation:Done writing observation heatmap thresholds.
# INFO [2023-01-12 13:48:57] Colors for breaks:  #00008B,#24249B,#4848AB,#6D6DBC,#9191CC,#B6B6DD,#DADAEE,#FFFFFF,#EEDADA,#DDB6B6,#CC9191,#BC6D6D,#AB4848,#9B2424,#8B0000
# INFO [2023-01-12 13:48:57] Quantiles of plotted data range: 1,3,3,3,6
# INFO [2023-01-12 13:48:58] plot_cnv_references:Start
# INFO [2023-01-12 13:48:58] Reference data size: Cells= 298 Genes= 8222
# INFO [2023-01-12 13:48:58] plot_cnv_references:Number reference groups= 9
# INFO [2023-01-12 13:48:58] plot_cnv_references:Plotting heatmap.
# INFO [2023-01-12 13:48:58] Colors for breaks:  #00008B,#24249B,#4848AB,#6D6DBC,#9191CC,#B6B6DD,#DADAEE,#FFFFFF,#EEDADA,#DDB6B6,#CC9191,#BC6D6D,#AB4848,#9B2424,#8B0000
# INFO [2023-01-12 13:48:58] Quantiles of plotted data range: 2,3,3,3,6
# INFO [2023-01-12 13:49:00]
#
# 	STEP 20: Converting HMM-based CNV states to repr expr vals
#
# INFO [2023-01-12 13:49:11] ::plot_cnv:Start
# INFO [2023-01-12 13:49:11] ::plot_cnv:Current data dimensions (r,c)=8222,1395 Total=12374558 Min=0 Max=3.
# INFO [2023-01-12 13:49:11] ::plot_cnv:Depending on the size of the matrix this may take a moment.
# INFO [2023-01-12 13:49:11] plot_cnv_observation:Start
# INFO [2023-01-12 13:49:11] Observation data size: Cells= 1097 Genes= 8222
# INFO [2023-01-12 13:49:11] plot_cnv_observation:Writing observation groupings/color.
# INFO [2023-01-12 13:49:11] plot_cnv_observation:Done writing observation groupings/color.
# INFO [2023-01-12 13:49:12] plot_cnv_observation:Writing observation heatmap thresholds.
# INFO [2023-01-12 13:49:12] plot_cnv_observation:Done writing observation heatmap thresholds.
# INFO [2023-01-12 13:49:13] Colors for breaks:  #00008B,#24249B,#4848AB,#6D6DBC,#9191CC,#B6B6DD,#DADAEE,#FFFFFF,#EEDADA,#DDB6B6,#CC9191,#BC6D6D,#AB4848,#9B2424,#8B0000
# INFO [2023-01-12 13:49:13] Quantiles of plotted data range: 0,1,1,1,3
# INFO [2023-01-12 13:49:14] plot_cnv_references:Start
# INFO [2023-01-12 13:49:15] Reference data size: Cells= 298 Genes= 8222
# INFO [2023-01-12 13:49:15] plot_cnv_references:Number reference groups= 9
# INFO [2023-01-12 13:49:15] plot_cnv_references:Plotting heatmap.
# INFO [2023-01-12 13:49:15] Colors for breaks:  #00008B,#24249B,#4848AB,#6D6DBC,#9191CC,#B6B6DD,#DADAEE,#FFFFFF,#EEDADA,#DDB6B6,#CC9191,#BC6D6D,#AB4848,#9B2424,#8B0000
# INFO [2023-01-12 13:49:15] Quantiles of plotted data range: 0.5,1,1,1,3
# INFO [2023-01-12 13:49:16]
#
# 	STEP 22: Denoising
#
# INFO [2023-01-12 13:49:16] ::process_data:Remove noise, noise threshold defined via ref mean sd_amplifier:  1.5
# INFO [2023-01-12 13:49:16] denoising using mean(normal) +- sd_amplifier * sd(normal) per gene per cell across all data
# INFO [2023-01-12 13:49:16] :: **** clear_noise_via_ref_quantiles **** : removing noise between bounds:  0.923902758771003 - 1.08102526847185
# INFO [2023-01-12 13:49:38]
#
# ## Making the final infercnv heatmap ##
# INFO [2023-01-12 13:49:39] ::plot_cnv:Start
# INFO [2023-01-12 13:49:39] ::plot_cnv:Current data dimensions (r,c)=8222,1395 Total=11596135.4996324 Min=0.533392748199964 Max=2.19260282630749.
# INFO [2023-01-12 13:49:39] ::plot_cnv:Depending on the size of the matrix this may take a moment.
# INFO [2023-01-12 13:49:39] plot_cnv(): auto thresholding at: (0.616543 , 1.383457)
# INFO [2023-01-12 13:49:40] plot_cnv_observation:Start
# INFO [2023-01-12 13:49:40] Observation data size: Cells= 1097 Genes= 8222
# INFO [2023-01-12 13:49:40] plot_cnv_observation:Writing observation groupings/color.
# INFO [2023-01-12 13:49:40] plot_cnv_observation:Done writing observation groupings/color.
# INFO [2023-01-12 13:49:40] plot_cnv_observation:Writing observation heatmap thresholds.
# INFO [2023-01-12 13:49:40] plot_cnv_observation:Done writing observation heatmap thresholds.
# INFO [2023-01-12 13:49:42] Colors for breaks:  #00008B,#24249B,#4848AB,#6D6DBC,#9191CC,#B6B6DD,#DADAEE,#FFFFFF,#EEDADA,#DDB6B6,#CC9191,#BC6D6D,#AB4848,#9B2424,#8B0000
# INFO [2023-01-12 13:49:42] Quantiles of plotted data range: 0.616543114856288,1.00246401362143,1.00246401362143,1.00246401362143,1.38345688514371
# INFO [2023-01-12 13:49:43] plot_cnv_references:Start
# INFO [2023-01-12 13:49:43] Reference data size: Cells= 298 Genes= 8222
# INFO [2023-01-12 13:49:43] plot_cnv_references:Number reference groups= 9
# INFO [2023-01-12 13:49:43] plot_cnv_references:Plotting heatmap.
# INFO [2023-01-12 13:49:43] Colors for breaks:  #00008B,#24249B,#4848AB,#6D6DBC,#9191CC,#B6B6DD,#DADAEE,#FFFFFF,#EEDADA,#DDB6B6,#CC9191,#BC6D6D,#AB4848,#9B2424,#8B0000
# INFO [2023-01-12 13:49:43] Quantiles of plotted data range: 0.703696876398357,1.00246401362143,1.00246401362143,1.00246401362143,1.38345688514371

# %%
saveRDS(infercnv_obj, file = "patient_tissue/00_infercnv_obj.rds")

# %% [markdown]
# # CNV heatmap using heatmap.3.R

# %%
infercnv_obj <- readRDS("patient_tissue/00_infercnv_obj.rds")

# %%
source("./heatmap.3.R")

# %%
# load results
res <- t(as.data.frame(infercnv_obj@expr.data))
dim(res)
res[1:2, 1:5]
# Out:
# [1] 1395 8222
#                    LINC01128 NOC2L    ISG15    C1orf159 SDF4
# CRC01_L1_Barcode01 1.175955  1.178252 1.181446 1.186522 1.189957
# CRC01_L1_Barcode02 1.002464  1.002464 1.002464 1.002464 1.002464

# %%
# genes order
gene_order <- read.table(file = "00_gene_ordering_file.txt", header = F)
colnames(gene_order) <- c("gene", "chr", "start", "end")
rownames(gene_order) <- gene_order$gene
gene_order <- gene_order[intersect(colnames(res), rownames(gene_order)), ]
gene_order$order <- c(1:length(gene_order$chr))
gene_order$chr <- factor(gene_order$chr, levels = c(
  "chr1", "chr2", "chr3", "chr4", "chr5", "chr6", "chr7", "chr8", "chr9", "chr10", "chr11",
  "chr12", "chr13", "chr14", "chr15", "chr16", "chr17", "chr18", "chr19", "chr20", "chr21", "chr22"
))
all(rownames(gene_order) == colnames(res))
head(gene_order, 2)
# Out:
# [1] TRUE
#           gene      chr  start  end    order
# LINC01128 LINC01128 chr1 825138 859446 1
# NOC2L     NOC2L     chr1 944203 959309 2

# %%
colnames(res) <- gene_order$order
head(res, 2)
# Out:
#                    1        2        3        4        5        6
# CRC01_L1_Barcode01 1.175955 1.178252 1.181446 1.186522 1.189957 1.194382
# CRC01_L1_Barcode02 1.002464 1.002464 1.002464 1.002464 1.002464 1.002464
#                    7        8        9        10       ⋯ 8213     8214
# CRC01_L1_Barcode01 1.198764 1.201530 1.204647 1.205138 ⋯ 1.002464 1.002464
# CRC01_L1_Barcode02 1.002464 1.002464 1.002464 1.002464 ⋯ 1.002464 1.002464
#                    8215     8216     8217     8218     8219     8220
# CRC01_L1_Barcode01 1.002464 1.002464 1.002464 1.002464 1.002464 1.002464
# CRC01_L1_Barcode02 1.002464 1.002464 1.002464 1.002464 1.002464 1.002464
#                    8221     8222
# CRC01_L1_Barcode01 1.002464 1.002464
# CRC01_L1_Barcode02 1.002464 1.002464

# %%
# load annotation file
ont <- readRDS(file = "../02_RNA_seurat/01_RNA_2184_1395_tx/00_tx_2184_1395_hvg1000_PC1_25.rds")
meta <- ont@meta.data[order(ont@meta.data$Tissue, ont@meta.data$celltype1, ont@meta.data$celltype3, ont@meta.data$patient), ]
head(meta, 2)
table(meta$Tissue)
# Out:
#                    orig.ident nCount_RNA nFeature_RNA CellName
# CRC01_L1_Barcode01 CRC01      274730.8   6733         CRC01_L1_Barcode01
# CRC01_L1_Barcode05 CRC01       10177.8    711         CRC01_L1_Barcode05
#                    library  patient library_sub tissue position barcode   ⋯
# CRC01_L1_Barcode01 CRC01_L1 CRC01   L1          NT     T1       Barcode01 ⋯
# CRC01_L1_Barcode05 CRC01_L1 CRC01   L1          NT     T1       Barcode05 ⋯
#                    PC_2        tSNE_1     tSNE_2    nCount_GENE nFeature_GENE
# CRC01_L1_Barcode01 -17.8032495 -17.989282 -12.42012 274730.8    4661
# CRC01_L1_Barcode05   0.3504461   5.427324 -11.93935  10177.8     545
#                    celltype1         celltype1_1 celltype1_2 celltype2
# CRC01_L1_Barcode01 Normal epithelium NE          NE          Stem/TA
# CRC01_L1_Barcode05 Normal epithelium NE          NE          Stem/TA
#                    celltype3
# CRC01_L1_Barcode01 Stem/TA
# CRC01_L1_Barcode05 Stem/TA
# Normal Tissue Primary Tumor
#           298          1097

# %%
res <- res[meta$CellName, ]
head(res, 2)
# Out:
#                    1        2        3        4        5        6
# CRC01_L1_Barcode01 1.175955 1.178252 1.181446 1.186522 1.189957 1.194382
# CRC01_L1_Barcode05 1.002464 1.002464 1.002464 1.002464 1.002464 1.002464
#                    7        8        9        10       ⋯ 8213     8214
# CRC01_L1_Barcode01 1.198764 1.201530 1.204647 1.205138 ⋯ 1.002464 1.002464
# CRC01_L1_Barcode05 1.002464 1.002464 1.002464 1.002464 ⋯ 1.002464 1.002464
#                    8215     8216     8217     8218     8219     8220
# CRC01_L1_Barcode01 1.002464 1.002464 1.002464 1.002464 1.002464 1.002464
# CRC01_L1_Barcode05 1.002464 1.002464 1.002464 1.002464 1.002464 1.002464
#                    8221     8222
# CRC01_L1_Barcode01 1.002464 1.002464
# CRC01_L1_Barcode05 1.002464 1.002464

# %%
# row annotation
df_rlab <- data.frame(
  row.names = meta$CellName,
  Patient = meta$patient,
  Subtype = meta$celltype3,
  Cell_type = meta$celltype1,
  Tissue = meta$Tissue
)
head(df_rlab, 1)
table(df_rlab$Patient)
table(df_rlab$Cell_type)
table(df_rlab$Subtype)
table(df_rlab$Tissue)
# Out:
#                    Patient Subtype Cell_type         Tissue
# CRC01_L1_Barcode01 CRC01   Stem/TA Normal epithelium Normal Tissue
# CRC01 CRC02 CRC03 CRC04 CRC05 CRC07 CRC08 CRC09 CRC10
#   165   122    91   100   164   275   132   204   142
# Normal epithelium      Cancer cells
#               374              1021
#                Stem/TA             Enterocyte        Immature Goblet
#                    186                     34                    117
#                 Goblet           Stem/TA-like   Immature Goblet-like
#                     37                    826                    186
# Goblet/Enterocyte-like
#                      9
# Normal Tissue Primary Tumor
#           298          1097

# %%
map_Patient <- data.frame(
  Patient = names(table(meta$patient)), Patient_colors = patient_color[c(1:9)]
)
map_Subtype <- data.frame(
  Subtype = names(table(meta$celltype3)), Subtype_colors = celltype3_color
)
map_Cell_type <- data.frame(
  Cell_type = names(table(meta$celltype1)), Cell_type_colors = celltype1_color
)
map_Tissue <- data.frame(
  Tissue = names(table(meta$Tissue)), Tissue_colors = tissue_color
)

# %%
df_rlab_colors <- df_rlab
df_rlab_colors$Patient <- map_Patient[match(df_rlab_colors$Patient, map_Patient$Patient), "Patient_colors"]
df_rlab_colors$Subtype <- map_Subtype[match(df_rlab_colors$Subtype, map_Subtype$Subtype), "Subtype_colors"]
df_rlab_colors$Cell_type <- map_Cell_type[match(df_rlab_colors$Cell_type, map_Cell_type$Cell_type), "Cell_type_colors"]
df_rlab_colors$Tissue <- map_Tissue[match(df_rlab_colors$Tissue, map_Tissue$Tissue), "Tissue_colors"]
df_rlab_colors <- as.matrix(t(df_rlab_colors))
df_rlab_colors
# Out:
#           CRC01_L1_Barcode01 CRC01_L1_Barcode05 CRC01_L1_Barcode09
# Patient   #FED439FF          #FED439FF          #FED439FF
# Subtype   #9467BDFF          #9467BDFF          #9467BDFF
# Cell_type #0072B5FF          #0072B5FF          #0072B5FF
# Tissue    #2CA02CFF          #2CA02CFF          #2CA02CFF
#           CRC01_L1_Barcode10 CRC01_L1_Barcode17 CRC01_L1_Barcode21
# Patient   #FED439FF          #FED439FF          #FED439FF
# Subtype   #9467BDFF          #9467BDFF          #9467BDFF
# Cell_type #0072B5FF          #0072B5FF          #0072B5FF
# Tissue    #2CA02CFF          #2CA02CFF          #2CA02CFF
#           CRC01_L1_Barcode22 CRC01_L1_Barcode30 CRC01_L1_Barcode31
# Patient   #FED439FF          #FED439FF          #FED439FF
# Subtype   #9467BDFF          #9467BDFF          #9467BDFF
# Cell_type #0072B5FF          #0072B5FF          #0072B5FF
# Tissue    #2CA02CFF          #2CA02CFF          #2CA02CFF
#           CRC01_L1_Barcode33 ⋯ CRC09_L4_CRC10_L2_Barcode93
# Patient   #FED439FF          ⋯ #71D0F5FF
# Subtype   #9467BDFF          ⋯ #FD7446FF
# Cell_type #0072B5FF          ⋯ #D62728FF
# Tissue    #2CA02CFF          ⋯ #E377C2FF
#           CRC09_L3_CRC10_L1_Barcode15 CRC09_L3_CRC10_L1_Barcode17
# Patient   #E377C2FF                   #E377C2FF
# Subtype   #FD7446FF                   #FD7446FF
# Cell_type #D62728FF                   #D62728FF
# Tissue    #E377C2FF                   #E377C2FF
#           CRC09_L3_CRC10_L1_Barcode31 CRC09_L4_CRC10_L2_Barcode21
# Patient   #E377C2FF                   #E377C2FF
# Subtype   #FD7446FF                   #FD7446FF
# Cell_type #D62728FF                   #D62728FF
# Tissue    #E377C2FF                   #E377C2FF
#           CRC01_L3_Barcode13 CRC01_L3_Barcode31 CRC04_L1_CRC07_L2_Barcode09
# Patient   #FED439FF          #FED439FF          #D5E4A2FF
# Subtype   #8A9197FF          #8A9197FF          #8A9197FF
# Cell_type #D62728FF          #D62728FF          #D62728FF
# Tissue    #E377C2FF          #E377C2FF          #E377C2FF
#           CRC09_L4_CRC10_L2_Barcode82 CRC09_L4_CRC10_L2_Barcode24
# Patient   #71D0F5FF                   #E377C2FF
# Subtype   #8A9197FF                   #8A9197FF
# Cell_type #D62728FF                   #D62728FF
# Tissue    #E377C2FF                   #E377C2FF

# %%
summary(as.numeric(res))
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  0.5334  1.0025  1.0025  1.0110  1.0025  2.1926

# %%
up_limit <- 2 - min(res)
res[res > up_limit] <- up_limit

# %%
# chromosome boundary line
bin_len <- as.data.frame(table(gene_order$chr))
# cumsum(bin_len$Freq)

v_lines <- c(1 + 3, cumsum(bin_len$Freq))
# v_lines
h_lines <- c(1 - 0.5, dim(res)[1] + 0.5)
# h_lines

# %%
mycol <- colorRampPalette(rev(c(
  rep("#b2182b", 1), rep("#d6604d", 1), rep("#f4a582", 1), rep("#fddbc7", 1),
  rep("#f7f7f7", 1), rep("#f7f7f7", 1),
  rep("#d1e5f0", 1), rep("#92c5de", 1), rep("#4393c3", 1), rep("#2166ac", 1)
)))(100)
# colorRampPalette(c(rep("blue",1), rep("white",1),rep("red",1)))(50)

# %%
# no clustering
pdf("1_heatmap_infercnv_nocluster.pdf", height = 10, width = 10)
heatmap.3(
  res,
  col = mycol,
  Rowv = FALSE, Colv = FALSE, dendrogram = "none", scale = "none",
  # hclustfun=myclust, distfun=mydist,na.rm = TRUE,
  # revC = FALSE,
  RowSideColors = df_rlab_colors, RowSideColorsSize = 1.5, # keysize = 1,
  add.expr = abline(
    h = c(1 - 0.5, table(meta$celltype1)[2], dim(res)[1] + 0.5), v = v_lines
  ),
  labCol = FALSE, labRow = FALSE, margins = c(25, 4)
)
dev.off()

# %%
# Define custom dist and hclust functions for use with heatmaps
mydist <- function(c) {
  dist(c, method = "euclidean")
}
myclust <- function(c) {
  hclust(c, method = "ward.D")
}

# %%
# clustering
pdf("1_heatmap_infercnv_cluster.pdf", height = 10, width = 10)
p_out <- heatmap.3(
  res,
  col = mycol,
  # row clustering
  Rowv = TRUE, Colv = FALSE, dendrogram = "row", scale = "none",
  # clustering function
  hclustfun = myclust, distfun = mydist, na.rm = TRUE,
  # rev based on results
  revC = TRUE,
  # row annotation
  RowSideColors = df_rlab_colors, RowSideColorsSize = 1.5,
  # add chromosome lines
  add.expr = abline(h = h_lines, v = v_lines),
  labCol = FALSE, labRow = FALSE, margins = c(25, 4)
)
dev.off()
